# %% [markdown]
# # display_category_words
#
# 2022/1/6
#
# category_words_dic作成のために、
# 各カテゴリーの文章をいくつか表示するノートブック

# %%
import json
import os
import glob

# %%
# 日本語
CATEGORY_SPLIT_DIR_PATH = '/home/nakachi/data/category_split'
CATEGORY_WORDS_DIC_PATH = os.path.join(CATEGORY_SPLIT_DIR_PATH, 'category_words_ja_dic.json')

# %%
with open(CATEGORY_WORDS_DIC_PATH) as f:
    category_words_dic = json.load(f)

# %%
# 何ファイル表示するか
MAX_DISPLAY_TEXT = 2

# %%
for cat in category_words_dic.keys():
    print(f'process {cat}...')
    cat_dir_path = os.path.join(CATEGORY_SPLIT_DIR_PATH, cat+'_ja')
    text_path_list = glob.glob(cat_dir_path + '/text/*')
    
    for i in range(MAX_DISPLAY_TEXT):
        with open(text_path_list[i+2]) as f:
            print(f.read())
    
    print('----------------------------------\n')
# Out:
# process person...
# いつく もの 自転車 が 売っ て いる 店内
# 自転車 ショップ の 店内 に 自転車 が 展示 さ れ て いる
# 自転車 屋 の 中 で 何 人 か の 客 が 外 を 見 て いる
# たくさん の 自転車 屋 サングラス が 売ら れ て いる 自転車 屋 さん
# 自転車 が 整然と 並び 人 で 賑わう お 店
# 携帯 電話 を いじっ て いる 電車 の 乗客
# 電車 で 座っ て いる 女性 が 携帯 を 持っ て いる
# アジア 系 の 人 たち が 電車 の 座席 に 座っ て いる
# 列車 に 乗っ た 女性 が 携帯 電話 を 見 て いる
# 電車 の 中 で 様々 な 人 が スマート フォン を 持っ て いる
# ----------------------------------
#
# process bicycle...
# 街 中 を たくさん の 人 が 歩い て いる
# 5 つ の 道 が 交わる 交差点 の 様子
# いくつ も の 道 に 分かれる 分岐 点 と そこ に 集まる お 店
# 魚眼レンズ で 撮影 し て ゆがん だ 誤差 路
# 六 差 路 の 交差点 を 人 と 車 と 自転車 が 行き交っ て いる
# いつく もの 自転車 が 売っ て いる 店内
# 自転車 ショップ の 店内 に 自転車 が 展示 さ れ て いる
# 自転車 屋 の 中 で 何 人 か の 客 が 外 を 見 て いる
# たくさん の 自転車 屋 サングラス が 売ら れ て いる 自転車 屋 さん
# 自転車 が 整然と 並び 人 で 賑わう お 店
# ----------------------------------
#
# process car...
# 道路 を 車 が 走っ て い て 、 上 に は 白い 飛行機 が 飛ん でる
# 沢山 の 車 の 上 を 飛行機 が 飛ん で いる
# 車 の 通る 道路 の 上空 で ジャンボ ジェット機 が 飛ん で いる
# 多く の 自動車 が 走る 道 の 上 を 飛行機 が 飛ん で いる
# 飛行 中 の 飛行機 から タイヤ 部分 が 出 て いる
# 路肩 に 荷物 置き場 の よう な もの が あり 、 その 中 に ド クロ 柄 の バッグ が 入っ て いる
# 青い オブジェ の 中 に ド クロ の 絵 が 描い て ある 袋 が 置い て ある
# ド クロ の 絵 が 描か れ た バック が 置か れ て いる
# ド クロ の 柄 の バッグ が 置い て ある
# パーキングメーター の 横 の 丸い 棚 に バッグ が 置か れ て いる
# ----------------------------------
#
# process motorcycle...
# トラック の 後方 に 赤い バイク に 乗っ た 人 が いる
# 緑色 の 小型 バス が 道路 を 走っ て いる 、 後ろ に は バイク が ある
# 黄 緑色 の バス の 横 に 赤い バス が 並ぼ う と し て いる
# 緑 の バス が 向こう 側 へ 走っ て いる
# 車線 の ない 道路 を 走る 緑色 の 古び た バス
# バイク の 後ろ に 乗っ て いる 男性 が 携帯 を 向け て いる
# バイク の 後部 に 乗っ て いる 女性 が スマ ホ を 見 て いる
# 白い 帽子 を 逆 に かぶっ た 男性 が バイク に 乗っ て いる
# バイク に 乗る 二 人 、 後ろ の 彼女 は 彼氏 の 耳 の 裏 を 盗 撮し て いる
# 男女 が バイク の 二 人 乗り を し て いる
# ----------------------------------
#
# process airplane...
# 1 機 の 飛行機 が 空 を 飛ん で いる
# くもり 空 の 上 を 飛ん で いる 一 台 の 飛行機
# エンジン が 二つ 後ろ に 付い た 旅客機 が 、 真上 を 飛ん で いる
# 曇り空 の 中 を 飛行機 が 飛ん で いる
# 空 を 飛ん で いる 旅客機 を 下 から 見 た ところ
# 夜 の 空港 にて 準備 中 の 大型 飛行機
# 飛行機 が 、 ライト に 照らさ れ て いる
# 夜 の 飛行場 に ある 白い 飛行機 で ある
# 空港 の 夜景 は 街 と は 違う 美し さ が ある
# 暗い 夜 の 中 に 飛行機 が 停 まっ て いる
# ----------------------------------
#
# process bus...
# トラック の 後方 に 赤い バイク に 乗っ た 人 が いる
# 緑色 の 小型 バス が 道路 を 走っ て いる 、 後ろ に は バイク が ある
# 黄 緑色 の バス の 横 に 赤い バス が 並ぼ う と し て いる
# 緑 の バス が 向こう 側 へ 走っ て いる
# 車線 の ない 道路 を 走る 緑色 の 古び た バス
# 街 中 を 数 台 の の 車 が ブレーキ ランプ を 光らせ 止まっ て いる
# スカイライン が 何 台 も 停車 し て いる
# 数 台 の 車 が 信号 待ち を し て いる
# 街 中 を たくさん の 車 が 走っ て いる
# 3 台 の クルマ が 信号 待ち を し て いる
# ----------------------------------
#
# process train...
# 橋 に 緑色 の 看板 が 複数 取り付け られ て いる
# 様々 な 行き先 が 書か れ た 看板 が たくさん 掲げ られ て ある
# 橋 の 所 に チェス ナット 通り と 書か れ た 標識 が ある
# 柱 の ある 大きな 屋根 の 建物 の 屋根 の 色 は 青い
# 橋 の 向こう に 黄色い 大きな 建物 が ある
# ホーム に 群青 色 の 列車 が 停車 し て いる
# 青い 電車 が フォーム に 停 まっ て いる
# 青い 電車 が ホーム に 停 まっ て いる
# 停車 し て いる 列車 の 前 を リュック を 背負っ た 男 が 歩い て いる
# ホーム に 車体 が 青 と 黄色 の First という 列車 が 停 まっ て いる
# ----------------------------------
#
# process truck...
# いつく もの 自転車 が 売っ て いる 店内
# 自転車 ショップ の 店内 に 自転車 が 展示 さ れ て いる
# 自転車 屋 の 中 で 何 人 か の 客 が 外 を 見 て いる
# たくさん の 自転車 屋 サングラス が 売ら れ て いる 自転車 屋 さん
# 自転車 が 整然と 並び 人 で 賑わう お 店
# 白い 車 が 花壇 の 向こう を 走っ て いる
# 花壇 の 中 に 赤い 道路 標識 が 立っ て いる
# 道路 の 一角 に ある 花壇 に 標識 が たっ て いる
# 白い 車 の 前 に 丸い 大きな 花壇 が あり 、 赤い 看板 が たて られ て いる
# 円形 の ロータリー に 白い 車 が 停め られ て いる
# ----------------------------------
#
# process boat...
# 荒波 の 中 で 男性 が カヌー を 漕い で いる
# オレンジ 色 の カヌー に 男性 が 乗っ て いる
# 黄色い ボート が 波 に 揉ま れ ながら 進ん で いる
# オレンジ の カヌー に 、 白い ヘルメット の 二 人 の 人物 が 乗っ て いる
# 子供 と 大人 が 荒れる 波 の 上 で カヤック を し て いる
# 大きな 船 が 車輪 の つい た 台 に のせ られ て いる
# 車輪 の 付い た 台 に のせ られ た 船 に 帽子 を 被っ た 人達 が 乗っ て いる
# 車輪 付き の 台 で 運ば れる 船 に 乗っ て いる 人々
# 台車 に 載せ られ た 船 の 上 に 、 数 人 の 男性 たち が 乗っ て いる
# 船 に 乗せ られ て 海 へ 向かお う と し て いる 男性 たち
# ----------------------------------
#
# process traffic light...
# 白い 縦長 の 路面 電車 が 自家用車 の 隣 に 止まっ て いる
# どこ か の 国 の どこ か の 駅 に 止まる トラム
# 道路 沿い の 電柱 と 電線 と 路面 電車 っぽい 乗り物
# 路面 電車 と 2 台 の 車 が 並ん で 走っ て いる
# 信号 で 停止 する 路面 電車 と 乗用車
# ソフトクリーム の 移動 販売 の 車 が 走っ て いる
# 男性 が アイスクリーム の トラック が 通過 し た ばかり の 道路 を 渡っ て いる
# 移動 販売 の 車 に 絵 が 描か れ て いる
# 男性 が ソフトクリーム の 屋台 の 後ろ を 歩い て いる
# 白 と 青 の トラック の 後ろ に 男 が 歩い て いる
# ----------------------------------
#
# process fire hydrant...
# 湖 の ほとり に 消火栓 が 設置 さ れ て いる
# 湖 の そば の 原っぱ に 雪 が 積もり 赤い 水 管 が ある
# 雪 が 残る 湖畔 と 赤い 給水 塔 の 夕方
# 雪原 に ある 赤い 消火栓 と 大きな 湖
# 枯れ 果て た 草木 の 上 に 雪 が 積もっ て いる
# 赤い 消火栓 に 鎖 が 垂れ下がっ て いる
# 街 の 中 に 真っ赤 な 消火栓 が ある
# 道端 の 赤い 物体 に つい た チェーン が 切れ て いる
# 1988 に 設置 さ れ た 真っ赤 な 消火栓
# 街 の 中 に 赤く 目立つ 消化 器 の 写真
# ----------------------------------
#
# process stop sign...
# 道路 が 大量 の 雪 で 覆わ れ て いる 様子 が 写っ て いる
# ストップ の 標識 が 雪 を 被っ て いる
# 木 の 枝 や 道路 標識 に も 雪 が 積もっ て いる
# 表札 も 道路 も 木 も 雪 に 覆わ れ て いる
# 地面 や 道端 に 立つ 標識 に 、 雪 が 積もっ て いる
# 白い 車 が 花壇 の 向こう を 走っ て いる
# 花壇 の 中 に 赤い 道路 標識 が 立っ て いる
# 道路 の 一角 に ある 花壇 に 標識 が たっ て いる
# 白い 車 の 前 に 丸い 大きな 花壇 が あり 、 赤い 看板 が たて られ て いる
# 円形 の ロータリー に 白い 車 が 停め られ て いる
# ----------------------------------
#
# process parking meter...
# 水滴 が つい た 茶色 の 多肉植物 が ある
# パーキング メータ の 前 に 水 に ぬれ た 花 が 咲い て いる
# 赤 茶色 の 花びら が 何 枚 も 折り重なっ て いる 花 が 咲い て いる
# 黒い 花 の 後ろ に 何 か が 移っ て いる
# 黒色 の 花びら の 花 が 一つ 咲い て いる
# 二つ の メーター の つい た パーキングメーター が 立っ て いる
# 道路 を 背景 に 立つ 2 台 分 の パーキングメーター
# TWOHOURTIMELIMIT と 書か れ た もの が 置い て ある
# 海外 の 道路 沿い に ある おしゃれ な コイン パーキング
# パーキング の 機械 の メータ 2 台 分 設置 さ れ て いる
# ----------------------------------
#
# process bench...
# 白い キッチン の 隣 に ソファー を 置い た リビング が ある
# 白い システム キッチン の 上 から 銀 の ランプ が 3 つ 下がっ て いる
# キッチン の 横 に リビング が あり その 隣 は 庭 に なっ て いる
# 白い 対面 型 の キッチン と ソファ が ある
# 白 を 基調 と し た キッチン と 奥 に ソファ が ある
# 女 の 人 が 男 の 人 と 肩 を 組ん で いる
# カメラ を 持っ た 男性 と 女性 が 肩 に 腕 を 組みあっ て 立っ て いる
# 空港 の 手荷物 引渡 所 で 記念 写真 を 撮る 男女
# カップル の 女性 が 、 カメラ の つい た Tシャツ を 着 て いる
# カメラ を 首 に 掛け た 男女 が 肩 に 手 を まわし て 立っ て いる
# ----------------------------------
#
# process bird...
# 一 羽 の 鳥 が 羽 を 広げ て 飛ん で いる
# 青い 鳥 が 体 を 斜め に し て 飛ん で いる
# 空 を 跳ん で いる カモメ の 後ろ姿
# 一 羽 の 鳥 が 濁っ た 海 の 上 を 飛ん で いる
# カモメ が 太陽 に 向かっ て 飛ん で いる 様子
# 白い カモメ が 青い 空 を 一 羽 飛ん で いる
# 青い 大空 を 悠然と 飛ぶ 一 羽 の 白い カモメ
# 青空 に 白い カモメ が 優雅 に 飛ん で いる
# 青い 空 を 横切っ て 、 カモメ が 一 羽 飛ん で いる
# 青い 空 を 飛ん で いる 白い 羽 の 鳥
# ----------------------------------
#
# process cat...
# ピンク の ニット 帽 を 被っ て いる 猫
# ピンク の 暖かい 帽子 を かぶせ られ た 黒 と 白 の 猫
# ピンク の 毛糸 帽 を 被っ た 黒白 柄 の 猫 が 絨毯 の 上 で 座っ て いる
# 黒 猫 が 紫 の ニット 帽 を かぶっ て いる
# 黒い 猫 が ピンク の 帽子 を 被っ て 座っ て いる
# 木 の 扉 の 上 で 猫 が つかまり ながら こちら を 見 て いる
# 高い 場所 に 横たわっ て 左手 と 尻尾 を 垂らし て いる 猫 で ある
# 白黒 の 毛 の 色 を し た 猫 は 高い ところ に 登っ て いる
# タンス の 上 に ハチワレ 模様 の 猫 が 乗っ て いる
# ドア の 上 に 黒 と 白 の 色 の 猫 が 乗っ て いる
# ----------------------------------
#
# process dog...
# 柵 の 中 で 黒い 犬 が 羊 たち を 見 て いる
# 羊 に 吠え ながら 追い詰め て いく 牧羊 犬
# 白 と 黒 の 色 を し た 犬 が 羊 に 向かっ て いる
# 羊 と 白黒 の 毛 の 犬 が 向かい合っ て いる
# 2 頭 の 羊 と 羊 を 見 て いる 黒い 犬
# 赤ちゃん を 背中 に おんぶ し て いる 男性 が 白い 二 匹 の 犬 の リード も 持っ て いる
# 子ども を 背負っ た 男性 が 二 頭 の 白い 大型 犬 を 散歩 さ せ て いる
# 犬 を たくさん 散歩 さ せ て いる たくさん の 外国 人 たち が いる
# 子供 を おんぶ し た 男性 が 赤い リード を つけ た 2 頭 に 犬 を 連れ て いる
# 赤ちゃん を 背負っ た 男性 が 、 2 匹 の 犬 を 散歩 さ せ て いる
# ----------------------------------
#
# process horse...
# 番号 が 書か れ て ある ゼッケン を つけ た 男女 が 馬 に 乗っ て 道 を 進ん で いる
# 山道 を 馬 に 乗り 移動 する ゼッケン を 付け た 人
# 赤い シャツ の 人 が 白い 馬 に 乗っ て いる
# ゼッケン を つけ 、 馬 に 乗っ た 人々 が 森 の 中 を 走っ て いる
# 杜 の 中 の 道 を 、 ゼッケン を 着け 馬 に 乗っ た 人々 が 進ん で いる
# 4 頭 の 馬 が 道路 脇 の 茂み の 前 に いる
# 道端 に 馬 が 数 頭 たたずん で いる
# 道路 の 脇 に 四 頭 の 馬 が 固まっ て 集まっ て いる
# 道路 脇 で 数 匹 の 馬 が 草 を 食べ て いる
# 道路 の 脇 の 草 を 馬 が 数 頭 食べ て いる
# ----------------------------------
#
# process sheep...
# しゃがん で 羊 の 頭 を 撫でる 女性 を 見下ろし て いる
# ヒツジ に 屈ん で 触っ て いる 人 が いる
# 茶色い 髪 の 女性 が 羊 の 頭 を 撫で て いる
# 羊 の 頭 を 撫で て いる 茶色 の 髪 の 長い 女性
# 羊 を 撫で て いる Tシャツ の 女性
# 1 頭 の 羊 が こちら 側 を 向い て いる
# 正面 を 向い 向い た 羊 と 後ろ を 向い た 羊 が いる
# 平原 で 4 頭 の 羊 が 草 を 食べ て いる
# 四 匹 の 羊 が 地面 の 草 を 食べ て いる
# 4 匹 の ひつじ が い て 1 匹 だけ こちら に 顔 を 向け て いる
# ----------------------------------
#
# process cow...
# 草原 の 中 に たくさん の 羊 たち が いる
# 草原 の 中 に 沢山 の 牛 が 集まっ て いる
# 牧草 地 で 黒い 牛 たち が 草 を 食べ て いる
# 牧場 の 牛 、 顔 だけ が 白い 一 頭 が こちら を 見 て いる
# 柵 の 向こう の 草むら に 馬 が たくさん いる
# 自然 豊か な 山の上 で 牛 が 後尾 を し て いる
# 広い 大地 の 中 で 野生 動物 の 繁殖 が 行わ れ て いる
# 野生 の 動物 が 荒野 で 交わっ て いる
# 交尾 し て いる 角 の 生え た 茶色い 牛
# 乾燥 し た 山の上 で 交尾 を する 茶色い 牛
# ----------------------------------
#
# process elephant...
# 象 が 乗っ た トラック に 藁 が ある
# トラック に 載せ られ た 象 が 鼻 を 伸ばし て いる
# 車 に 乗っ て いる 象 の 前 に 草 が 沢山 置い て ある
# トラック の 中 に 1 匹 の 象 が 入っ て いる
# 小屋 の 中 の 象 に エサ を 与え て いる
# ゾウ が 水たまり の 中 に 入り 水浴び を し て いる
# 象 が 水 場 で 水浴び を し ながら 鼻 を 上 に 上げ て いる
# プール の 水 で 水浴び を する 動物 園 の 象
# 一 頭 の 象 が 水 に 身体 の ほとんど を 浸け て 鼻 を 上げ て いる
# ゾウ が プール に 入り 水浴び を し て いる
# ----------------------------------
#
# process bear...
# 熊 どうし が 仲良く じゃれ あっ て 遊ん で いる
# 黒い クマ が 二 頭 で 毛 づく ろ い を し て いる
# 熊 が もう 一 頭 の クマ の 首 元 に 口 を 寄せ て いる
# 鼻先 の 白い 二 匹 の 黒い くま が じゃれ あっ て いる
# 柵 の 横 で 2 頭 の 黒い 熊 が 寄り添っ て いる
# 中 に 果物 を 入れ た 自動車 の 形 の 氷 を 舐め て いる パンダ
# パンダ は オレンジ 色 の 車 の 形 を し た もの を 舐め て いる
# これ は 、 パンダ でも 食べ られる ケーキ で ある
# 1 頭 の パンダ が 、 一生懸命 舐め て いる
# パンダ が オレンジ 色 の 物 に つい た 霜 を 舐め て いる
# ----------------------------------
#
# process zebra...
# しまうま 4 頭 の 群れ の 中 に キリン 1 頭 が 混じっ て いる
# 草原 の 中 で シマウマ たち と キリン が 立っ て いる
# 草原 に キリン と 数 頭 の シマウマ が 居る
# シマウマ の 奥 に キリン が 1 頭 いる
# 芝生 の 上 に 四 頭 の シマウマ が いる
# シマウマ が 、 木 の 根元 に 置か れ た 干し草 を 食べ て いる
# シマウマ が 地面 に ある 藁 を 食べ て いる
# 木の下 の 草 を 食べ て いる シマウマ
# 柵 の 中 の シマウマ が 草 を 食べ て いる
# 木の下 に 置か れ た 草 を 食べ て いる シマウマ と 、 横たわっ て いる シマウマ
# ----------------------------------
#
# process giraffe...
# キリン が 3 頭 草原 に 座っ て いる
# 木々 の 立ち並ぶ 中 に 、 何 頭 か の キリン が 、 足 を 折っ て 休ん で いる
# 草むら に キリン が 3 頭 座っ て いる
# 草原 で 野生 の キリン が 休憩 し て いる
# 草原 に 3 頭 の キリン が 座り込ん で いる
# 一 匹 の キリン が 別 の キリン の 背中 に 顔 を 乗せ て いる
# キリン の 背中 に もう 一 頭 の キリン が 顔 を うずめ て いる
# 1 匹 の キリン の 首 に 頭 を 乗せる もう 1 匹 の キリン
# キリン の 背中 に 隣 の キリン が 顔 を 乗せ て いる
# 心 癒さ れる キリン の 親子 の 写真
# ----------------------------------
#
# process backpack...
# 海岸 で 二 人 の 女性 が 馬 に 乗っ て いる
# 女性 二 人 が 馬 に 乗っ て 海岸 沿い を 歩い て いる
# 馬 に 乗っ た 女性 が 二 人 、 海辺 を 歩い て いる
# 海辺 で 女 が 二 人馬 に それぞれ 乗っ て いる
# 海岸 で 女性 二 人 が 馬 に 乗っ て 散歩 し て いる
# テーブル の 上 を スケボー で ジャンプ し て いる
# 緑色 の 帽子 を かぶっ て いる 男 は スケボー を し て いる
# 帽子 を 被っ た 男性 が スケート ボード を し て いる
# 緑 の 帽子 を かぶっ た 眼鏡 の 男性 が テーブル の 上 を スケボー で 飛ん で いる
# 男性 が スケート ボード で 技 を 披露 する
# ----------------------------------
#
# process umbrella...
# 白い 服 を 着 た 男性 が 携帯 電話 を 使用 し て いる
# 黒い 傘 を 差し た 男性 が 電話 を かけ て いる
# 十字架 と 傘 を 持っ た ターバン の 男性 が 電話 し てる
# 黒い 傘 を 差し た 男性 が 携帯 電話 を 使用 し て いる
# 白い 服 の 男性 が 傘 を さして 携帯 電話 で 話し て いる
# ピンク の 建物 の 前 に 白い テラス の カフェ が ある
# レストラン に 入ろ う か 迷っ て いる 人 たち
# ピンク色 の 建物 の 前 に 3 人 の 女性 が 立っ て いる
# ピンク の 建物 が 立っ て い て 、 手前 に ピンク の テーブル 掛け が ある
# ここ は 市民 プール な ので 、 安価 で 楽しむ こと が できる
# ----------------------------------
#
# process handbag...
# いつく もの 自転車 が 売っ て いる 店内
# 自転車 ショップ の 店内 に 自転車 が 展示 さ れ て いる
# 自転車 屋 の 中 で 何 人 か の 客 が 外 を 見 て いる
# たくさん の 自転車 屋 サングラス が 売ら れ て いる 自転車 屋 さん
# 自転車 が 整然と 並び 人 で 賑わう お 店
# 携帯 電話 を いじっ て いる 電車 の 乗客
# 電車 で 座っ て いる 女性 が 携帯 を 持っ て いる
# アジア 系 の 人 たち が 電車 の 座席 に 座っ て いる
# 列車 に 乗っ た 女性 が 携帯 電話 を 見 て いる
# 電車 の 中 で 様々 な 人 が スマート フォン を 持っ て いる
# ----------------------------------
#
# process tie...
# 長い 行列 で 疲れ て しまっ た 少年
# たくさん の 人 が 行列 を 作っ て 待っ て いる
# お金 の 換金 に 並ぶ 両親 を まつ 子供
# 銀行 に 押し寄せ て いる 人々 の 様子
# 両替 所 に 並ん で いる 男性 達 と 荷物 の 番 を し て いる 男の子
# 男女 の マネキン が 服 を 着せ られ て おか れ て いる
# 服 を 着る 透明 な 男女 の マネキン
# 頭 の ない 男女 の マネキン が 置い て ある よう だ
# 黒い スーツ と 黄色い ワンピース を 着 た 2 体 の マネキン が 立っ て いる
# 男性 と 女性 の 服装 を 着 た 首 の ない マネキン で ある
# ----------------------------------
#
# process suitcase...
# ホーム に 群青 色 の 列車 が 停車 し て いる
# 青い 電車 が フォーム に 停 まっ て いる
# 青い 電車 が ホーム に 停 まっ て いる
# 停車 し て いる 列車 の 前 を リュック を 背負っ た 男 が 歩い て いる
# ホーム に 車体 が 青 と 黄色 の First という 列車 が 停 まっ て いる
# チェック の ベッド の 上 に 鞄 や 服 が 散乱 し て いる
# 部屋 の 中 に たくさん の 本 が ある
# たくさん の 本 が 積ま れ て いる 机 で ある
# チェック の カバー が 掛かっ た ベッド の 上 に ベージュ の 鞄 や 新聞紙 が 重ね て 置い て ある
# 雑多 な 部屋 の 中 で 脱ぎ捨て た 服 や 読みかけ の 本 が 散乱 し て いる
# ----------------------------------
#
# process frisbee...
# 赤い シャツ を 着 た 男性 が ジャンプ し て フリスビー を キャッチ し て いる
# 赤い Tシャツ の 男性 が ジャンプ し て 白い フリスビー を キャッチ し て いる
# フリスビー を キャッチ する 赤 い服 の 男性
# 赤い Tシャツ の 男性 が ジャンプ し て いる
# 広場 で フライングソーサー を キャッチ する 男性
# 芝生 で 犬 が 緑 の フリスビー を 咥 え て いる
# 赤い テント が あっ たり 、 犬 が 走っ て いる
# 公園 で 黒い 犬 が 緑色 の おもちゃ を くわえ て 走っ て いる
# 犬 が フリスビー を くわえ て 走っ て いる
# 犬 が フリスビー を 咥 えて 芝生 を 走っ て いる
# ----------------------------------
#
# process skis...
# 黒い ウェア を 着 た 男性 が スキー を し て いる
# スキー を 履い た 男 が 記念 撮影 を し て いる
# 黒 の サングラス を かけ た 男性 が スキー を し て いる
# 雪山 を スキー で 移動 し て いる 男性 が こちら を 見 て いる
# スキー を する ため に やってき た 男性
# オレンジ 色 の ジャンパー を 着 た 男性 が スキー を し て いる
# ミニ スキー を 履い た 男性 が 、 雪山 の 上 から 下 を 見下ろし て いる
# オレンジ 色 の 服 の 人 が スキー を し て いる
# 雪山 で ショート スキー と スティック を 持っ た 男性 が 山 を 見下ろし て いる
# ショート スキー で 今 から 滑り 下りよ う と する 人
# ----------------------------------
#
# process snowboard...
# ヘルメット を かぶっ た 人 が スノーボード を 履い て いる
# 白い 雪 の 上 で スノーボード し て いる 男
# 中央 で スノーボード に 乗っ た 男性 が 笑顔 で 立っ て いる
# 夜 に スノーボード を し て いる 笑顔 の 人
# スノーボード を し て いる 男性 で ある
# 高く ジャンプ を し て いる スノーボーダー
# スノーボード に 乗っ た 人 で ある
# 白い ジャケット の 男 は スノボー を し て いる
# スノーボード で 飛ん で いる 人 が いる
# 空 に 向かっ て ジャンプ する スノーボーダー
# ----------------------------------
#
# process sports ball...
# とれる か とれ ない か の ボール を 拾う テニス プレイヤー
# 白い ユニフォーム を 着 た テニス プレーヤー が ボール を 受け止めよ う と し て いる
# 白い シャツ の 男性 の テニス プレイヤー で ある
# テニス の 試合 中 に ボール を 追っかける 選手
# テニス プレーヤー が テニス ボール を 追いかけ て いる
# 公園 で 、 少年 が カイト 凧 を 上げ て いる
# 芝生 の 上 で 凧 揚げ を する 子供 たち
# 芝生 の 広場 で 男の子 が カイト を 飛ばし て いる
# 親子 が 原っぱ で カラフル な 凧 を 揚げ て いる
# 公園 で カラフル な 凧 を 揚げ て いる
# ----------------------------------
#
# process kite...
# 砂浜 で 鳥 の 形 を し た 凧 を 揚げ て いる 人 が いる
# 海岸 で 男性 が カイト を あげ て いる
# 海辺 の 砂浜 で 男性 が 派手 な 凧 を 飛ばし て いる
# 青空 の 下 、 白い 砂浜 で 凧 を あげる 男
# 男性 が 海辺 で 赤い 凧 を 飛ばし て いる
# 白い 洋服 の ポニーテール を し た 男性 が 右 上 を 見 て いる
# 2 人 の 人 が 大きな 鳥 の 凧 を 見上げ て いる
# 広場 で 巨大 な カラフル な 人形 が 浮い て いる
# 動物 の かたち を し た バルーン が 芝生 で 飛ばさ れ て いる
# ふくろう がた の タコ の よう な もの が 揚がっ て いる
# ----------------------------------
#
# process baseball bat...
# 野球 を し て いる 少年 が バット で 球 を 打ち返そ う と し て いる
# 少年 野球 チーム の 試合 で 、 バッター が バット に ボール を 当て て いる
# 子供 が バット で 球 を 打と う と し て いる
# 少年 野球 の 試合 で バッター が バット を 振っ た
# オレンジ の ユニフォーム を 着 た 男性 が バット を 振っ て いる
# バッティング を し て いる 人 が いる
# 紺 と 白 の ユニホーム で 赤い 靴 の 選手 が バット を 構え て いる
# 濃紺 の ユニフォーム を 着 た 男性 が 野球 を プレー し て いる
# 野球 の バッティング 練習 を する 人 たち
# 黒 と 白 の ユニフォーム を 着 た 男性 が 木製 の バット を 持っ て いる
# ----------------------------------
#
# process baseball glove...
# 野球 を し て いる 少年 が バット で 球 を 打ち返そ う と し て いる
# 少年 野球 チーム の 試合 で 、 バッター が バット に ボール を 当て て いる
# 子供 が バット で 球 を 打と う と し て いる
# 少年 野球 の 試合 で バッター が バット を 振っ た
# オレンジ の ユニフォーム を 着 た 男性 が バット を 振っ て いる
# 野球 選手 が マウンド で 投球 を し て いる
# 室内 球場 で ピッチャー が バッター に ボール を 投げよ う と し て いる 瞬間 だ
# 札幌 ドーム で の プロ 野球 の 試合
# ピッチャー が 振りかぶっ て まさに 今 投げ て いる
# 球場 で プロ 野球 が 行わ れ て いる
# ----------------------------------
#
# process skateboard...
# 男性 が スケート ボード に 手 と 膝 を つい て 乗っ て いる
# 男性 が スケート ボード に 乗っ て いる
# 黒い パーカー を 着 た 男性 が スケート ボード に 乗っ て いる
# スケボー の 上 に のっ て 走らす 男性
# スケート ボード に 四つん這い で 乗る 人
# 少年 たち が 集団 で スケボー に 乗っ て いる
# 広い アスファルト を スケート ボード で 進む 人 たち
# テレビ 画面 に スケート ボード を し て いる 男性 たち が 映っ て いる
# 五 人 の 人 が ボード に 乗っ て 走っ て いる
# 5 人 の 人間 が こちら へ 向かっ て スケート ボード に 乗っ て いる
# ----------------------------------
#
# process surfboard...
# 上半身 裸 の 男性 が サーフ ボード の 上 に 立っ て いる
# 上半身 は だ か の 男性 が サーフィン を し て いる
# 男 が ひとり 、 サーフィン を 楽しん で いる
# 透明 度 の 高い 海 で サーフィン を する 男性 は 日 に 焼け て いる
# 半 ズボン だけ で サーフィン を する 男性
# サー ファー が パドリング し て いる
# サーフ ボード に 寝 て 乗っ て いる
# 波 に あわせ て パドリング する サー ファー
# パドリング を し て いる 黒い ウェット スーツ の 少年
# 大きな 波 の 海 で 、 サーフ ボード に 乗る 少年
# ----------------------------------
#
# process tennis racket...
# 黒 の タンク トップ の 女性 が テニス を し て いる
# 黒い タンク トップ を 着 た 女性 が ラケット を 持っ て いる
# テニス ウェア で ラケット を 持つ 女性
# ポニーテール の 女性 テニス プレイヤー が ラケット を 持っ て 立っ て いる
# 金髪 の 女性 が テニス を し て いる
# 膝 に ピンク色 の テーピング を し て いる テニス 選手
# 右足 に テーピング を し た 女性 が テニス を し て いる
# 足 に テープ を 張っ た 女性 が テニス を し て いる
# 右足 に ピンク色 の テーピング を し た 女性 が テニス の ラケット を 振っ て いる
# コート で テニス スポーツ を する 女性
# ----------------------------------
#
# process bottle...
# 便器 が 水色 の 壁 に くっつい て いる
# 水色 の 壁 に トイレ が 埋め込ん で 設置 さ れ て いる
# 洗面 所 、 青い 壁 に 取り付け られ た 便器 が ある が タンク や トイレットペーパー が 見当たら ない
# ブルー の 壁 の 部屋 に 洋式 トイレ と 洗面 台 が ある
# 洗面 台 の そば に タオル が 掛かっ て いる
# 木 の 板 に 置か れ た ピザ を 切っ て いる
# ピザ カッター で ピザ を 切り分け て いる
# まな板 の 上 に ピザ が あり 、 切り取っ て いる
# テーブル の 上 の ピザ を カッター で 切っ て いる
# 木 の テーブル に 載っ た 木 の トレー の 上 の ピザ を ルーラー で カット し て いる
# ----------------------------------
#
# process wine glass...
# サングラス を かけ た 女性 が ピザ の 入っ た のっ た お 皿 を 持っ て いる
# サングラス の 女性 が カフェ で ピザ の 皿 を もっ て いる
# サングラス の 女 が ピザ を 見せ て いる
# 青い 洋服 を 着 て サングラス を 頭 に つけ た 女 が ナス の 乗っ た ピザ の 皿 を 持っ て いる
# 青い 服 を 着 た 人 が ピザ の 乗っ た 皿 を 持ち 笑っ て いる
# 男女 の テディベア の 前 に は グラス と 髪 が 置か れ て いる
# くま の ぬいぐるみ が テーブル に 座っ て いる
# タキシード と ウエディングドレス を 着 た ペア の 熊 の ぬいぐるみ が 、 なら んで 座っ て いる
# 熊 の 人形 の 花婿 と 花嫁 が 並ん で 座っ て いる
# ウェディング ドレス を 着 た 熊 の ぬいぐるみ が 座っ て いる
# ----------------------------------
#
# process cup...
# パン や サラダ が 乗っ た お 皿 の 手前 に コーラ が たっぷり 入っ た ペプシ の 紙 コップ が ある
# ランチ の 飲料 は ペプシ の 紙 コップ に 入っ た コーラ
# 机 の 上 に コーラ と ご飯 が 置か れ て いる
# 飲み物 の 入っ た カップ と 料理 の 乗っ た 皿 が テーブル の 上 に 置か れ て いる
# ドレッシング の かかっ た サラダ と ペプシコーラ
# 店 で 注文 し た 商品 を 店内 に 置い て いる
# 机 の 上 に は 3 つ の ドーナッツ と フォーク が 置か れ て いる
# 壁際 の テーブル に 1 つ ずつ 皿 に 乗っ た ドーナツ と フォーク が 並ん で いる
# カウンター に ドーナツ が 3 つ 並ん で いる
# 机 の 上 に 3 つ の ドーナツ と 3 本 の フォーク が 並ん で いる
# ----------------------------------
#
# process fork...
# テーブル の 上 に ドリンク と 食事 が 置い て ある
# テーブル の 上 に ハンバーガー と スープ が ある
# 机 の 上 に 料理 と 飲み物 が 置い て ある
# ピンク の カゴ に 紙 を 敷い て 食べ物 が のっ て いる
# テーブル の 上 に 料理 が 乗っ て いる
# 木 の 板 に 置か れ た ピザ を 切っ て いる
# ピザ カッター で ピザ を 切り分け て いる
# まな板 の 上 に ピザ が あり 、 切り取っ て いる
# テーブル の 上 の ピザ を カッター で 切っ て いる
# 木 の テーブル に 載っ た 木 の トレー の 上 の ピザ を ルーラー で カット し て いる
# ----------------------------------
#
# process knife...
# 玉子 と トースト と コーヒー が おい て ある
# 喫茶店 で 朝 の 食事 を とっ て いる
# 皿 に は 玉子 焼き と パン が 乗っ て いる
# クレープ と クッキー と コーヒー が 机 の 上 に 置い て ある
# 4 枚 の トースト と オムレツ が 白い 皿 の 上 に 乗っ て いる
# キッチン の 台 の 上 に プレート が あり その 上 に は クッキー が ある
# キッチン の 方 を 人 が 左手 で 指さし て いる
# 瓶 や コーヒー メーカー が 置い て ある 台所
# ビン や 包丁 が 綺麗 に 並ん で いる 、 キッチン の コーナー
# 人 が 冷蔵庫 に 向かっ て 指 を さし て いる
# ----------------------------------
#
# process spoon...
# テーブル の 上 に クロワッサン と コーヒー が 置い て ある
# クロワッサン と カフェラテ と エスプレッソ の 乗る テーブル
# バスケット に 入っ た クロワッサン と 、 2 杯 の コーヒー
# クロワッサン と コーヒー が テーブル に 置か れ て いる
# テーブル の 上 に コーヒー と パン が 置か れ て いる
# テーブル の 上 に ドリンク と 食事 が 置い て ある
# テーブル の 上 に ハンバーガー と スープ が ある
# 机 の 上 に 料理 と 飲み物 が 置い て ある
# ピンク の カゴ に 紙 を 敷い て 食べ物 が のっ て いる
# テーブル の 上 に 料理 が 乗っ て いる
# ----------------------------------
#
# process bowl...
# 調理 台 に 立つ エプロン の 男 を 見 て いる 女
# オープン カウンター で 料理 を する 男性
# 緑 の まな板 を 使っ て 調理 を し て いる 人
# 外国 の レストラン で 客 の 前 で 料理 を し て いる 人 が いる
# キッチン に 立っ た 男性 が 料理 を し て いる
# 緑 と 白 の ブロッコリー と 人参 が ある
# ブロッコリー 、 カリフラワー 、 ベビーキャロット が 皿 に 乗っ て いる
# ブロッコリー と カリフラワー と 人参 が 重なっ て いる
# 人参 と カリフラワー と ブロッコリー が 並ん で いる
# ブロッコリー と カリフラワー と 人参 が のっ て いる
# ----------------------------------
#
# process banana...
# まだ 熟し て い ない バナナ の 実 が 生る バナナ の 木
# バナナ の 木 に 緑 の バナナ の 花 が なっ て いる
# 青い バナナ が たくさん なっ て いる
# まだ 青い たくさん の バナナ が 木 の 上 に なっ て いる
# バナナ の 木 に 実 が なっ て い て 、 蕾 も つい て いる
# 白い 紙 の 上 に パン が 乗っ て いる
# バナナ を 入れ た パンケーキ を 半分 に 折っ て 手 に 持っ て いる
# 生地 に スライス し た バナナ を 入れ た 、 薄い ホットケーキ の よう な 物 を 持っ て いる
# 白い 紙 の 上 に バナナ の 入っ た 焼き 菓子 が 乗っ て いる
# 焼い た スポンジ 生地 の 中 に バナナ が 入っ て いる
# ----------------------------------
#
# process apple...
# 赤い 車 が 歩道 の 側 に 停 まっ て いる
# 露天商 で 箱 に 入っ た リンゴ が 売ら れれ て いる
# リンゴ が たくさん 木 箱 に 入っ て いる
# たくさん の リンゴ が 木 の 箱 に 入っ て いる
# 複数 の 木製 の かご に 色 味 の 違う 林檎 が 入っ て いる
# 女性 が お客 さん に スイカ を 渡し て いる
# 女性 が 袋 に 入っ た 一 切れ の スイカ を 渡し て いる
# 女性 が 袋 に 入っ た 食べ物 を 渡し て いる
# 金髪 の 女性 が 、 スイカ を 渡し て いる
# カット フルーツ を 売っ て いる 女性
# ----------------------------------
#
# process sandwich...
# パン や サラダ が 乗っ た お 皿 の 手前 に コーラ が たっぷり 入っ た ペプシ の 紙 コップ が ある
# ランチ の 飲料 は ペプシ の 紙 コップ に 入っ た コーラ
# 机 の 上 に コーラ と ご飯 が 置か れ て いる
# 飲み物 の 入っ た カップ と 料理 の 乗っ た 皿 が テーブル の 上 に 置か れ て いる
# ドレッシング の かかっ た サラダ と ペプシコーラ
# 皿 の 上 に 食べ かけ の サンドイッチ が ある
# 皿 に サンドウィッチ が のっ て いる
# 紫 の 皿 の 上 に サンドイッチ が 置か れ て いる
# お 皿 の 上 に 食べ かけ の サンドイッチ が 置い て ある
# 青い 皿 に 盛り付け られ た サンドウィッチ
# ----------------------------------
#
# process orange...
# 黄色い リンゴ の 入っ た ケース を 男性 が 運ん で いる
# リンゴ が たくさん 入っ て いる 黄色 の 箱 を 持つ 人
# オレンジ 色 の 帽子 の 男性 が 、 黄色い フルーツ の 入っ た 黄色い 箱 を 持っ て いる
# オレンジ の 帽子 を かぶっ た 男性 が 黄色い リンゴ が 入っ た コンテナ を 持っ て いる
# 黄色い プラスチック ケース に 入っ た たくさん の 果物
# 女性 が お客 さん に スイカ を 渡し て いる
# 女性 が 袋 に 入っ た 一 切れ の スイカ を 渡し て いる
# 女性 が 袋 に 入っ た 食べ物 を 渡し て いる
# 金髪 の 女性 が 、 スイカ を 渡し て いる
# カット フルーツ を 売っ て いる 女性
# ----------------------------------
#
# process broccoli...
# 皿 の 上 に ブロッコリー と 肉 が のっ て いる
# シルバー の 器 の 中 に 入っ て いる 焼か れ た ブロッコリー と 肉
# ビーフステーキ と ブロッコリー の 温 サラダ で ある
# 皿 に 入っ た 厚い ステーキ と ブロッコリー
# 丸い 容器 に 肉 と ブロッコリー の 料理 が 入っ た 写真
# 白い 皿 に ブロッコリー が 盛り付け られ て いる
# 白い お 皿 に 山盛り の ブロッコリー が 盛ら れ て いる
# 白い 皿 に 茹で た ブロッコリー が 盛ら れ て いる
# 白い お 皿 の 上 に たくさん の ブロッコリー が のっ て いる
# ゆで られ た ブロッコリー が 白い 皿 に 盛ら れ て いる
# ----------------------------------
#
# process carrot...
# 肉 と 海老 と 野菜 の 入っ た に ゅうめん
# エビ や 人参 が 入っ た 麺 料理 で ある
# えび と 人参 の のっ た に ゅうめん
# レンゲ と 箸 の 横 に エビ の 乗っ た 麺 が 置い て ある
# そう めん に えび と 人参 と 肉 の 入っ た 汁 椀
# ニンジン や サクランボ や イチゴ が 置い て ある
# ブロッコリー や さくらんぼ で ある
# ニンジン と ブロッコリー 、 カリフラワー 等 の 野菜 と 、 サクランボ や イチゴ 等 の 果物 が 、 並べて 置か れ て いる
# 机 の 上 に 果物 と 野菜 が 並ん で いる
# カリフラワー 、 いちご 、 ブロッコリー など が テーブル の 上 に 置か れ て いる
# ----------------------------------
#
# process hot dog...
# ショーケース に カップ ケーキ が 並ん で いる
# ケース の 中 に は マフィン や ドーナツ など が ある
# 様々 な 種類 の マフィン が 並ん で いる
# クリア ケース の 中 に カップ ケーキ が 並ん で いる
# カップ ケーキ や スコーン が ケース の 中 に 入れ て ある
# 食べ かけ の ホット ドック が お 皿 に 乗っ て いる
# お 皿 の 上 に 食べ かけ の ホット ドック が 置い て ある
# 皿 の 上 に 、 ウィンナー と 野菜 の 入っ た 食べ かけ の ホットドッグ が 置い て ある
# 皿 に ホットドッグ が 乗っ て いる
# 一 枚 の お 皿 の 上 に ホットドッグ が 乗っ て いる
# ----------------------------------
#
# process pizza...
# 生 ハム の のっ た ピザ を 焼こ う と し て いる
# 鉄板 の 前 に は 大きな ピザ が 置い て ある
# バジルペースト に チーズ と ベーコン が 乗っ て いる 焼く 前 の ピザ
# トッピング を 盛り つけ 、 ピザ わ おや こう と し て いる
# 焼く 前 の ベーコーン が たくさん トッピング さ れ た ピッツァ が 置い て ある
# ハム が 乗っ た 大きな ピザ が 三 切れ ある
# お 皿 に は ピザ が 3 切れ 残っ て いる
# カット さ れ た サラミ の のっ た ピザ が 3 つ ある
# 6 等分 さ れ た 内 の 3 枚 の ピザ が ある
# サラミ が 乗っ て いる ピザ が 切り分け られ て いる
# ----------------------------------
#
# process donut...
# 6 種類 の デザート が 箱 の 中 で 区切ら れ て 詰め て ある
# 甘 そう な ドーナツ が 6 個 並ん で いる
# 6 つ の 色々 な 種類 の ドーナツ が 箱 に 入っ て いる
# 6 種類 の ドーナツ が 箱詰め さ れ て いる
# 六 個 の 色々 な ドーナッツ を 仕切っ た 様子
# 店 で 注文 し た 商品 を 店内 に 置い て いる
# 机 の 上 に は 3 つ の ドーナッツ と フォーク が 置か れ て いる
# 壁際 の テーブル に 1 つ ずつ 皿 に 乗っ た ドーナツ と フォーク が 並ん で いる
# カウンター に ドーナツ が 3 つ 並ん で いる
# 机 の 上 に 3 つ の ドーナツ と 3 本 の フォーク が 並ん で いる
# ----------------------------------
#
# process cake...
# たくさん の 種類 の 、 ベリー が 乗っ た ケーキ の 内 の 一つ を 切り分け て いる 男性
# 男性 が フルーツ が のっ た ケーキ を 切っ て いる
# おいし そう な ベリー の 乗っ た ケーキ を 切り分け て いる 男性 が いる
# たくさん の ケーキ が 並ぶ 屋台 で 、 ケーキ に ナイフ を いれる 黒人 の 少年
# 紅白 の テント の 下 で ケーキ を 取り分け て いる 女性
# ウエディングドレス を 着 た 女性 と 手 に お 皿 を 持っ た 女性 が 立っ て いる
# オレンジ 色 の 髪 を し た 女性 が 花嫁 と 話 を し て いる
# 結婚式 の 新婦 と ケーキ を 持っ た 友人
# ウエディングドレス を 着 た 女性 と その 隣 に ケーキ を 持っ た 女性
# 赤い 髪 の 女性 が ケーキ を 持っ て いる
# ----------------------------------
#
# process chair...
# パン や サラダ が 乗っ た お 皿 の 手前 に コーラ が たっぷり 入っ た ペプシ の 紙 コップ が ある
# ランチ の 飲料 は ペプシ の 紙 コップ に 入っ た コーラ
# 机 の 上 に コーラ と ご飯 が 置か れ て いる
# 飲み物 の 入っ た カップ と 料理 の 乗っ た 皿 が テーブル の 上 に 置か れ て いる
# ドレッシング の かかっ た サラダ と ペプシコーラ
# 緑色 の 洋服 を 着 た 女性 が こちら を 向い て いる
# 巨大 な ケーキ を 前 に 笑い 顔 の 女性
# 女性 が 料理 を 前 に し て 笑顔 を 浮かべ て いる
# 女性 の 顔 より も 大きい パイ が お 皿 に 乗っ て いる
# 大きな 食べ かけ の パイ と 緑色 の 服 の 女性
# ----------------------------------
#
# process couch...
# 部屋 の 天井 に 球体 で 暖色 系 の 照明 が ある
# 赤い ソファ が あり 、 丸い 照明 が 光っ て いる
# 和紙 の 照明 を 使っ た 白い 壁紙 の 部屋
# アジ アンチック な 照明 の 部屋 に 赤い ソファー が 映える
# 部屋 に は ソファ ベッド 、 テレビ 、 プリンター など が 置か れ て いる
# 高い 家具 を 配置 し て い ない シンプル な 部屋
# 部屋 の 壁 に 星 型 の オブジェ が 飾ら れ て いる
# 本棚 が 整理 さ れ た 落ち着い た 部屋 だ
# ノート パソコン が 机 の 上 に 置か れ て いる
# 壁 に は 星 型 の オブジェ が 飾ら れ て いる
# ----------------------------------
#
# process potted plant...
# 白い 壁 と 赤い 床 に 白い 便器 が 設置 さ れ て いる
# 赤い タイル の 床 に 白い 洋式 便器 が ある
# トイレ に は 、 水洗 式 の 白い 洋式 トイレ が ある
# 洗面 所 の 上 に オレンジ の 花 が 置い て ある
# 赤 と 白 の タイル に 囲ま れ た 白い トイレ
# ピンク の 建物 の 前 に 白い テラス の カフェ が ある
# レストラン に 入ろ う か 迷っ て いる 人 たち
# ピンク色 の 建物 の 前 に 3 人 の 女性 が 立っ て いる
# ピンク の 建物 が 立っ て い て 、 手前 に ピンク の テーブル 掛け が ある
# ここ は 市民 プール な ので 、 安価 で 楽しむ こと が できる
# ----------------------------------
#
# process bed...
# 左側 の ベッド の 枕 カバー は 青い 右側 は 白い
# 部屋 に は 青い ベット カバー の ダブル ベット が ある
# ベッド に 窓 から 光 が 射し て いる
# 小さい ベット が 2 つ 横並び に し て ある
# ツイン ベッド の 部屋 に 太陽 の 光 が 差し込ん で いる
# 奥 に バス ルーム が あり 、 手前 に ベッド が ある
# ベッド ルーム から 見 た バス ルーム で ある
# 引き戸 の 向こう に 浴槽 が 見える
# ベット の 横 の 扉 の 奥 に は 浴槽 が ある
# バス タブ の ある お 風呂 と ベット る ー む
# ----------------------------------
#
# process dining table...
# テーブル の 上 を スケボー で ジャンプ し て いる
# 緑色 の 帽子 を かぶっ て いる 男 は スケボー を し て いる
# 帽子 を 被っ た 男性 が スケート ボード を し て いる
# 緑 の 帽子 を かぶっ た 眼鏡 の 男性 が テーブル の 上 を スケボー で 飛ん で いる
# 男性 が スケート ボード で 技 を 披露 する
# 木 の 板 に 置か れ た ピザ を 切っ て いる
# ピザ カッター で ピザ を 切り分け て いる
# まな板 の 上 に ピザ が あり 、 切り取っ て いる
# テーブル の 上 の ピザ を カッター で 切っ て いる
# 木 の テーブル に 載っ た 木 の トレー の 上 の ピザ を ルーラー で カット し て いる
# ----------------------------------
#
# process toilet...
# トイレ の 床 に トイレットペーパー が 散らかっ て いる
# トイレ の トイレットペーパー が 長く 引き出さ れ て 床 に 散らかっ て いる
# トイレットペーパー が 何者 か に ひき づら れ た 跡
# トイレットペーパー が 便器 周り に ちらかっ て いる
# 洋式 トイレ の 傍ら で トイレットペーパー が 散乱 し て いる
# ユニット バス の 中 の 便器 の 上 に 黒 猫 が いる
# 猫 が 便座 の 上 から こっち を 見 て いる
# 蓋 の 空い た 洋式 トイレ の 便座 に 黒い 猫 が 乗っ て いる
# 毛 の 長い 猫 が トイレ の 便座 の 上 に 座っ て いる
# 白い トイレ の 上 に 黒 猫 が 座っ て いる
# ----------------------------------
#
# process tv...
# テレビ の 横 に クリスマスツリー が 置い て ある
# 大きな テレビ が 置い て あり 、 隣 に は クリスマスツリー が ある 部屋
# クリスマスツリー が 飾ら れ て いる リビング に テレビ と ソファー が 置い て ある
# テレビ と テーブル 、 ソファー が 置か れ て いる
# テレビ に ソファ 、 ロー テーブル など が 置か れ クリスマスツリー が 飾ら れ た 部屋
# ベッド の そば に イス と 机 が ある
# 沢山 の 光 が 差し込む 男性 の 部屋 で ある
# ベッド と パソコン デスク の ある 部屋 に 光 が 差し込ん で いる
# 窓 から 日光 が 入る 、 壁 に フレーム が 掛け て ある 部屋
# 柔らか な 光 が 窓 から 降り注ぎ 、 部屋 を 明るく 照らす
# ----------------------------------
#
# process laptop...
# ノート パソコン の 横 に ケース が 積み上げ られ て いる
# デスク に ノート パソコン が 置い て ある
# ノート パソコン の 左 に CD ケース が 積み 上がっ て いる
# ノート パソコン の 隣 に は 山積み に なっ た CD たち が ある
# テーブル に 開い た ノート パソコン と 、 隣 に たくさん の CD ケース が 置い て ある
# パソコン の 前 に 座っ た 男性 が 振り返っ て いる
# 黄色い 服 の 男性 が パソコン の 前 に 座っ て こちら を 見 て いる
# 男性 が パソコン を 開い て こちら を み て いる
# 左 ひじ を 棚 に 乗せ た 白 シャツ の 男性 が パソコン の 前 で こちら を 見 て 座っ て いる
# 家 の 中 で パソコン で 作業 する ポロシャツ の 男性
# ----------------------------------
#
# process mouse...
# 皿 の 上 に 食べ かけ の サンドイッチ が ある
# 皿 に サンドウィッチ が のっ て いる
# 紫 の 皿 の 上 に サンドイッチ が 置か れ て いる
# お 皿 の 上 に 食べ かけ の サンドイッチ が 置い て ある
# 青い 皿 に 盛り付け られ た サンドウィッチ
# パソコン の モニター の 前 に 多数 の フィギュア と 黒い Tシャツ を 着 た 男 が いる
# フィギア が 何 体 も あり 、 パソコン の 画面 に も 、 アニメ が 写っ てる
# 机 の 上 に パソコン と フィギュア が 並ん で いる
# 白人 男性 と パソコン の 近く に フィギュア が たくさん ある
# テーブル の 上 に 置か れ た 沢山 の パソコン と フィギュア の 部屋 に いる 男性
# ----------------------------------
#
# process remote...
# 左側 に は 誰 か の お 尻 が あり 、 右側 に は テレビ 画面 が うつっ て いる
# テレビ 画面 の 前 で 白い コントローラー を 持っ て 立っ て いる 人 の 後ろ姿
# これから Wii の ゲーム を する のに 自分 の キャラクター を 作っ て いる
# 女性 で ビデオ ゲーム で 遊ん で いる
# テレビ に wii で 顔 を 作る 画面 が 映り 、 それ を 操作 する ひと の お 尻
# Wii リモコン と 追加 パック を 合体 さ せる アタッチメント
# 銃 の よう に 構え られる ゲーム の コントローラー だ
# wii リモコン を 銃 の 形 を し た もの に 付け て 持っ て いる
# ゲーム の コントローラー を 持っ て いる
# Wii の ゲーム 機 を 人 が 握っ て いる
# ----------------------------------
#
# process keyboard...
# 三 台 の パソコン の 前 に ヘッドホン が 置い て ある
# キーボード の 前 に 3 つ の パソコン 画面 が ある
# ノート パソコン と ディスプレイ 2 つ に キーボード
# モニター が たくさん 並ん だ デスク の 上
# 2 台 の ディスプレイ と 1 台 の キーボード と ノート パソコン 、 ヘッド フォン が 並ん で いる
# 街 中 に 放置 さ れ て いる キーボード と 椅子
# 路上 に 椅子 が あり 、 その 上 に キーボード が ある
# 外 に キーボード の 乗っ た 椅子 が 放置 さ れ て いる
# 歩道 に 生え た 木 の 横 に 椅子 が 2 つ 置い て あり 手前 の 椅子 の 上 に は キーボード が 置か れ て いる
# 歩道 に 置い て ある 椅子 の 上 に キーボード が 置い て ある
# ----------------------------------
#
# process cell phone...
# 檻 の 中 の 女性 たち に 携帯 電話 を 向け て いる
# 檻 の 向こう で ドレス を 着 た 人 が しがみつい て い て 、 それ を 赤ちゃん を 抱い た 男性 が 写真 を 撮っ て いる
# 牢屋 に 閉じ込め られ て いる 人 を 撮る 父親 と 娘
# 伝統 的 な ドレス を 着 た 人 たち が 入っ て いる 檻 の 前 で 小さな 子供 を 抱え た 男性 が 携帯 電話 で 写真 を 撮ろ う と し て いる
# 檻 に 仮装 を し た 人 たち が 閉じ込め られ て いる の を 女の子 を 抱っこ し ながら 男性 が スマート フォン で 写真 を 撮っ て いる
# 白い 服 を 着 た 男性 が 携帯 電話 を 使用 し て いる
# 黒い 傘 を 差し た 男性 が 電話 を かけ て いる
# 十字架 と 傘 を 持っ た ターバン の 男性 が 電話 し てる
# 黒い 傘 を 差し た 男性 が 携帯 電話 を 使用 し て いる
# 白い 服 の 男性 が 傘 を さして 携帯 電話 で 話し て いる
# ----------------------------------
#
# process microwave...
# 海外 の とっても 整理 整頓 が さ れ て いる キッチン
# 白 を 基調 と し た キッチン の 手前 に ある 冷蔵庫 に は たくさん ステッカー が 貼ら れ て いる
# 白い テーブル の 上 に ボーダー の 帽子 が 乗っ て いる
# 木 枠 の 窓 の 前 に 流し台 が ある キッチン
# フローリング の キッチン に 置か れ た 白い テーブル に 、 カゴ 、 帽子 、 キッチン タオル が ある
# キッチン と 同室 に ベッド が 置か れ て いる
# 花 柄 の ベッド カバー と 白い 枕 カバー が し て ある ベッド
# 晴れ た 日 の ベッド ルーム と キッチン
# 窓 の 向こう を 白い 車 が 走っ て いる
# キッチン に 小さな テーブル の 他 ベッド が ある
# ----------------------------------
#
# process oven...
# 生 ハム の のっ た ピザ を 焼こ う と し て いる
# 鉄板 の 前 に は 大きな ピザ が 置い て ある
# バジルペースト に チーズ と ベーコン が 乗っ て いる 焼く 前 の ピザ
# トッピング を 盛り つけ 、 ピザ わ おや こう と し て いる
# 焼く 前 の ベーコーン が たくさん トッピング さ れ た ピッツァ が 置い て ある
# 市松 模様 の 床 と 黒い オーブン が ある キッチン
# 台所 に 白い 冷蔵庫 が 置い て ある
# キッチン に 白い 冷蔵庫 が 置か れ て いる
# 冷蔵庫 の 上部 に ステッカー を いくつ も 張っ て ある
# 黒い キッチン コンロ と オーブン が ある キッチン の 冷蔵庫 の 扉 に 写真 や 書類 が たくさん 貼ら れ て いる
# ----------------------------------
#
# process toaster...
# 白人 男性 が 鍋 の 中身 を かき回し て いる
# 満面 の 笑み で 料理 を し て いる 男性
# フライパン で 料理 を 作っ て いる 男性 が 微笑ん で いる
# 料理 を し ながら カメラ 目線 で ポーズ を 決める 男性
# 煮込み 料理 を 作っ て いる 外国 人 男性
# 黒 を 基調 と し た コ の 字 型 の キッチン と アイランドテーブル が ある
# 黒 と シルバー の 新しい キッチン が ある
# エル 字 型 の キッチン に オーブン が 二 つつい て いる
# キッチン の 使い やす さ を 追求 し たら 、 キッチン 台 が 2 つ あれ ば 良い という こと に なっ た
# 黒色 基調 の システム キッチン の 中央 に は テーブル が ある
# ----------------------------------
#
# process sink...
# 白い キッチン の 隣 に ソファー を 置い た リビング が ある
# 白い システム キッチン の 上 から 銀 の ランプ が 3 つ 下がっ て いる
# キッチン の 横 に リビング が あり その 隣 は 庭 に なっ て いる
# 白い 対面 型 の キッチン と ソファ が ある
# 白 を 基調 と し た キッチン と 奥 に ソファ が ある
# キッチン の 台 の 上 に プレート が あり その 上 に は クッキー が ある
# キッチン の 方 を 人 が 左手 で 指さし て いる
# 瓶 や コーヒー メーカー が 置い て ある 台所
# ビン や 包丁 が 綺麗 に 並ん で いる 、 キッチン の コーナー
# 人 が 冷蔵庫 に 向かっ て 指 を さし て いる
# ----------------------------------
#
# process refrigerator...
# 卵 が たくさん 入っ て いる 冷蔵庫
# 冷蔵庫 の 中 に たくさん 卵 が 入っ て いる
# 冷蔵庫 の 中 に は 、 卵 の パック が 沢山 入っ て いる
# 冷蔵庫 の 中 に 卵 が 10 ケース 入っ て いる
# 冷蔵庫 の 中 に 卵 パック が たくさん ある
# 冷蔵庫 の 中 に 白い 液体 の 入っ た チューブ が 立て られ て いる
# 色々 な 飲み物 が 入っ て いる 冷蔵庫 の 中
# 健康 の ため に 毎日 飲む ドリンク を 量っ て 置い て いる
# 冷蔵庫 の 中 に 異なる 量 の 白い 液体 が 入っ た ケース が 並べ られ て いる
# 冷蔵庫 の 中 に 白い 液体 が 入っ た 容器 が 並ん で いる
# ----------------------------------
#
# process book...
# ベッド の そば に イス と 机 が ある
# 沢山 の 光 が 差し込む 男性 の 部屋 で ある
# ベッド と パソコン デスク の ある 部屋 に 光 が 差し込ん で いる
# 窓 から 日光 が 入る 、 壁 に フレーム が 掛け て ある 部屋
# 柔らか な 光 が 窓 から 降り注ぎ 、 部屋 を 明るく 照らす
# 高い 家具 を 配置 し て い ない シンプル な 部屋
# 部屋 の 壁 に 星 型 の オブジェ が 飾ら れ て いる
# 本棚 が 整理 さ れ た 落ち着い た 部屋 だ
# ノート パソコン が 机 の 上 に 置か れ て いる
# 壁 に は 星 型 の オブジェ が 飾ら れ て いる
# ----------------------------------
#
# process clock...
# 奥 に バス ルーム が あり 、 手前 に ベッド が ある
# ベッド ルーム から 見 た バス ルーム で ある
# 引き戸 の 向こう に 浴槽 が 見える
# ベット の 横 の 扉 の 奥 に は 浴槽 が ある
# バス タブ の ある お 風呂 と ベット る ー む
# サングラス を かけ た 男性 たち が バイク に 乗っ て いる
# 長年 バイク を 乗りこなし て き た よう な 人 が 群れ を 作っ て ツーリング し て いる
# サングラス で オートバイ に のっ て いる 高齢 の 男性 たち
# 街 中 に バイク に 乗っ て 走っ て いる 人 が たくさん いる
# バイク に 乗っ た 人 が 何 人 か いる
# ----------------------------------
#
# process vase...
# 便器 が 水色 の 壁 に くっつい て いる
# 水色 の 壁 に トイレ が 埋め込ん で 設置 さ れ て いる
# 洗面 所 、 青い 壁 に 取り付け られ た 便器 が ある が タンク や トイレットペーパー が 見当たら ない
# ブルー の 壁 の 部屋 に 洋式 トイレ と 洗面 台 が ある
# 洗面 台 の そば に タオル が 掛かっ て いる
# 白い 部屋 に 白い 花 が 生け て ある
# 窓際 に 白い 花瓶 に 活け られ た 花 が 置い て ある
# 窓 の そば に 花 が 入っ た 白い ポット が 置か れ て いる
# 白い 模様 の 書か れ 壁 に 出窓 が つい て いる
# 窓際 に 白い 花瓶 に 白い 花 が 生け て ある
# ----------------------------------
#
# process scissors...
# カラフル な 布 と ハサミ と 白い 紙 が 置い て ある
# 白い 紙 と 白い はさみ と カラフル な 布 が 置い て ある
# 黄色 茶色 緑色 赤 グレー の 布 の 前 に 大きな 白い 無地 の 布 と ハサミ が 置い て ある
# 数種類 の フェルト と 白い 画用紙 が 置か れ て いる
# 赤 や 緑 など 色々 な 紙 と ハサミ が 置か れ て いる
# キルティング の 鍋 つかみ が 4 個 も ある
# フック に 調理 器具 が かかっ て いる
# キッチン 用品 が 、 壁 に ぶら下がっ て いる
# 壁 に はさみ や キッチン 用品 が つるさ れ て いる
# 棚 に かかっ た はさみ や お たま 等 で ある
# ----------------------------------
#
# process teddy bear...
# 紫 と ピンク の つなぎ を 着 た 赤ちゃん が 哺乳 瓶 や ぬいぐるみ に かこま れ て ぐっすり 眠っ て いる
# 赤ちゃん が 哺乳 瓶 の 側 で 寝 て いる
# ベッド の 上 に 紫 の 服 の 赤ちゃん が 寝 て いる
# 子供 が ベッド の 上 で 眠っ て い て 、 傍ら に は 空 の 哺乳 瓶 が ある
# ピンク と 紫 の 服 を 着 た 赤ちゃん が ぬいぐるみ の 横 で 眠っ て いる
# 黒い ぬいぐるみ の 後ろ姿 越し の 青い 海
# 後ろ姿 の 熊 の ぬいぐるみ は 海 の 方向 を 見 て いる
# 黒い 熊 の ぬいぐるみ が サボテン を 持っ て 下 を 見 て いる
# 熊 の 形 を し た 物体 の 向こう に は 大きな サボテン と 広い 海原 が ある
# 黒色 の 熊 の ぬいぐるみ が 海 を 見 て いる
# ----------------------------------
#
# process hair drier...
# 指輪 を し た 黒髪 の 女 が ドライヤー を 持っ て いる
# 黒髪 の 女 が 両手 に ドライヤー を 構え て いる
# 黄色 の シャツ を 着 た 女 の 人 が ドライヤー を 持っ て いる
# ヘア ドライヤー を 銃 の よう に 構え て いる 女性
# ドライヤー を 持っ た 女性 で ある
# カーテン の 前 で 女性 が ドライヤー を 髪 に 当て て いる
# 右手 に ドライヤー を 持っ た 人 が 立っ て いる
# カーテン の 前 で ドライヤー を 使う 女性
# 女性 が ドライヤー を し ながら 立っ て いる
# 女性 が 立っ た まま 、 ドライヤー で 髪 を 乾かし て いる
# ----------------------------------
#
# process toothbrush...
# シャワー ルーム が ガラス 扉 で 仕切ら れ た バス ルーム
# 新築 の 我が家 の 自慢 の トイレ と バス ルーム
# 天井 に 窓 が ある 日当たり の よい トイレ と お 風呂 が 一体 に なっ た 部屋
# 白い トイレ の 天井 に 天窓 が ある
# トイレ の 天井 が 勾配 に なっ て いる
# ベット の すぐ そば に ある 洗面 台 で 歯 を 磨く 女性
# ピンク色 の 服 を 北 女性 が 洗面 台 に 向かっ て 立ち 膝 を 付い て いる
# 洗面 器 に むかっ て 女性 が 歯 を 磨い て いる
# 眼鏡 を かけ た 女性 が ベット の 上 から 洗面 台 を 覗い て いる
# 洗面 台 により かかっ て いる 、 眼鏡 を し た 女性 が いる
# ----------------------------------

# %%
for i in range(2):
    print(i)
# Out:
# 0
# 1
