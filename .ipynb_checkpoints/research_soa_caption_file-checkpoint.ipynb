# %% [markdown]
# # research_soa_caption_file

# %% [markdown]
# SOAの `SOA/capitions` の中にあるファイルを調べるノートブック

# %%
import pickle
import os

# %%
captions_dir = '/home/nakachi/data/semantic-object-accuracy-for-generative-text-to-image-synthesis/SOA/captions'
captions_file = 'label_31_snowboard.pkl'
captions_path = os.path.join(captions_dir, captions_file)

# %%
with open(captions_path, 'rb') as f:
    captions = pickle.load(f)

# %%
captions
# Out:
# [{'idx': [17, 3],
#   'image_id': 488720,
#   'id': 383963,
#   'caption': 'A person on a snowboard in the snow.'},
#  {'idx': [17, 4],
#   'image_id': 488720,
#   'id': 385427,
#   'caption': 'A man that is riding a snowboard on a mountain.'},
#  {'idx': [26, 0],
#   'image_id': 506356,
#   'id': 572400,
#   'caption': 'A man holding a snowboard in his right hand.'},
#  {'idx': [26, 1],
#   'image_id': 506356,
#   'id': 573801,
#   'caption': 'A person posing next to a snowboard in the snow '},
#  {'idx': [26, 2],
#   'image_id': 506356,
#   'id': 578667,
#   'caption': 'A person standing next to a snowboard on a field.'},
#  {'idx': [26, 3],
#   'image_id': 506356,
#   'id': 579648,
#   'caption': 'a person is standing next to their snowboard outside'},
#  {'idx': [172, 2],
#   'image_id': 244931,
#   'id': 133439,
#   'caption': 'A person on a snowboard sitting in the snow.'},
#  {'idx': [172, 3],
#   'image_id': 244931,
#   'id': 134639,
#   'caption': 'Man sitting down on a snow trail with his snowboard on his feet. '},
#  {'idx': [172, 4],
#   'image_id': 244931,
#   'id': 136742,
#   'caption': 'Someone on a snowboard coming to a stop.'},
#  {'idx': [181, 0],
#   'image_id': 446232,
#   'id': 128199,
#   'caption': 'a snow border snowboards on a snowy path'},
#  {'idx': [181, 1],
#   'image_id': 446232,
#   'id': 128277,
#   'caption': 'A boy on a snowboard on a flat surface'},
#  {'idx': [181, 2],
#   'image_id': 446232,
#   'id': 129060,
#   'caption': 'A person is using a snowboard on a mountain.'},
#  {'idx': [181, 4],
#   'image_id': 446232,
#   'id': 151266,
#   'caption': 'A person standing on a snowboard in winter.'},
#  {'idx': [216, 0],
#   'image_id': 32331,
#   'id': 375489,
#   'caption': 'A couple of people with snowboards in the snow.'},
#  {'idx': [216, 3],
#   'image_id': 32331,
#   'id': 386538,
#   'caption': 'a guy on a snow board and another person standing there'},
#  {'idx': [225, 0],
#   'image_id': 475229,
#   'id': 215392,
#   'caption': 'A person holding a snowboard standing on a snow covered slope.'},
#  {'idx': [225, 3],
#   'image_id': 475229,
#   'id': 239977,
#   'caption': 'A smiling person holding a snowboard standing on a snow covered hill.'},
#  {'idx': [225, 4],
#   'image_id': 475229,
#   'id': 242569,
#   'caption': 'A man holding a snowboard while bending in the snow.'},
#  {'idx': [293, 3],
#   'image_id': 214447,
#   'id': 48388,
#   'caption': 'A boy on a snowboard on a snowy field.'},
#  {'idx': [293, 4],
#   'image_id': 214447,
#   'id': 48847,
#   'caption': 'A man riding a snowboard down a  snow covered hill.'},
#  {'idx': [631, 2],
#   'image_id': 307768,
#   'id': 284471,
#   'caption': 'A man wearing a helmet and goggles on a snowboard reads a map while another snowboarder sits behind him.'},
#  {'idx': [676, 0],
#   'image_id': 570678,
#   'id': 727964,
#   'caption': 'A person in cold weather gear riding on a snowboard down a slope. '},
#  {'idx': [676, 4],
#   'image_id': 570678,
#   'id': 732029,
#   'caption': 'a person riding a snow board on a snowy slope'},
#  {'idx': [719, 0],
#   'image_id': 38886,
#   'id': 686051,
#   'caption': 'The person is standing on a snowboard wearing goggles.'},
#  {'idx': [719, 1],
#   'image_id': 38886,
#   'id': 689822,
#   'caption': 'A man riding a snowboard on top of a snow covered slope.'},
#  {'idx': [719, 4],
#   'image_id': 38886,
#   'id': 690923,
#   'caption': 'A person standing on a snowboard in the snow. '},
#  {'idx': [740, 0],
#   'image_id': 293057,
#   'id': 306746,
#   'caption': 'A person is on a snowboard on a ramp.'},
#  {'idx': [740, 3],
#   'image_id': 293057,
#   'id': 311258,
#   'caption': 'A person on a snowboard jumping off a pile of snow.'},
#  {'idx': [740, 4],
#   'image_id': 293057,
#   'id': 312236,
#   'caption': 'a person jumping a snow board in the air'},
#  {'idx': [834, 0],
#   'image_id': 526133,
#   'id': 629612,
#   'caption': 'A snowboard sits on the ground partially covered in powder.'},
#  {'idx': [834, 1],
#   'image_id': 526133,
#   'id': 631151,
#   'caption': 'a snow board sits on some snow '},
#  {'idx': [834, 2],
#   'image_id': 526133,
#   'id': 633836,
#   'caption': 'A snow covered snowboard sits on the snow covered ground.'},
#  {'idx': [834, 3],
#   'image_id': 526133,
#   'id': 641927,
#   'caption': 'A snowboard laying on snow covered ground covered in snow.'},
#  {'idx': [834, 4],
#   'image_id': 526133,
#   'id': 643592,
#   'caption': 'A snowboard lies in the snow, partly covered by snow.'},
#  {'idx': [860, 0],
#   'image_id': 285497,
#   'id': 394120,
#   'caption': "Two people in the snow one on a snowboard the other on ski's."},
#  {'idx': [860, 1],
#   'image_id': 285497,
#   'id': 394453,
#   'caption': 'A person on skis and a person on a snowboard are on a ski slope.'},
#  {'idx': [860, 3],
#   'image_id': 285497,
#   'id': 398581,
#   'caption': 'Two women in grey jackets on skis and snowboard next to mountains.'},
#  {'idx': [868, 2],
#   'image_id': 142934,
#   'id': 486510,
#   'caption': 'Two people carrying snowboards on a mountain slope. '},
#  {'idx': [916, 0],
#   'image_id': 285462,
#   'id': 439960,
#   'caption': 'A woman holding a snow board in one hand and her other arm in the air. '},
#  {'idx': [916, 1],
#   'image_id': 285462,
#   'id': 441571,
#   'caption': 'A woman with a snowboard in the snow.'},
#  {'idx': [1006, 4],
#   'image_id': 204609,
#   'id': 826011,
#   'caption': 'a man that is on a snowboard on a side of a hill'},
#  {'idx': [1103, 2],
#   'image_id': 216050,
#   'id': 148148,
#   'caption': 'A person laying back on a snowboard in the snow.'},
#  {'idx': [1140, 1],
#   'image_id': 355552,
#   'id': 463289,
#   'caption': 'A group of people holding snowboards on a deck.'},
#  {'idx': [1140, 3],
#   'image_id': 355552,
#   'id': 466784,
#   'caption': 'a number of people holding a snow board '},
#  {'idx': [1184, 2],
#   'image_id': 566518,
#   'id': 75188,
#   'caption': 'A young man riding a snowboard through the air above a mountain.'},
#  {'idx': [1185, 4],
#   'image_id': 22626,
#   'id': 74317,
#   'caption': 'legs on a snowboard looking down a steep slope.'},
#  {'idx': [1453, 0],
#   'image_id': 304817,
#   'id': 272603,
#   'caption': 'Snowboard stuck in a thick collection of trees. '},
#  {'idx': [1453, 1],
#   'image_id': 304817,
#   'id': 274670,
#   'caption': 'A snow board sticking out of the side of a tree.'},
#  {'idx': [1453, 3],
#   'image_id': 304817,
#   'id': 279365,
#   'caption': 'a close up of a snow board in a bush'},
#  {'idx': [1453, 4],
#   'image_id': 304817,
#   'id': 280229,
#   'caption': 'Snowboard atop of wooden structure next to evergreen plant.'},
#  {'idx': [1583, 0],
#   'image_id': 68525,
#   'id': 82994,
#   'caption': 'A man holding a snowboard next to two ski poles.'},
#  {'idx': [1583, 2],
#   'image_id': 68525,
#   'id': 88586,
#   'caption': 'Showing off his snowboard on a beautiful mountain.'},
#  {'idx': [1583, 3],
#   'image_id': 68525,
#   'id': 92321,
#   'caption': 'a person standing next to a snow board with mountains in the background'},
#  {'idx': [1619, 1],
#   'image_id': 291537,
#   'id': 458120,
#   'caption': 'A person is riding a snowboard down a mountain.'},
#  {'idx': [1619, 4],
#   'image_id': 291537,
#   'id': 820328,
#   'caption': 'A person riding a snowboard down a snowy slope.'},
#  {'idx': [1737, 0],
#   'image_id': 441472,
#   'id': 76740,
#   'caption': 'A man riding a snowboard on a snow covered  hill.'},
#  {'idx': [1737, 3],
#   'image_id': 441472,
#   'id': 83160,
#   'caption': 'a person riding a snow board on a small hill of snow'},
#  {'idx': [2029, 1],
#   'image_id': 258330,
#   'id': 97672,
#   'caption': 'A person on a snowboard on a snowy path.'},
#  {'idx': [2029, 3],
#   'image_id': 258330,
#   'id': 98863,
#   'caption': 'A man on a snowboard going down a hill.'},
#  {'idx': [2039, 4],
#   'image_id': 357335,
#   'id': 62008,
#   'caption': 'A man riding a snowboard down a snow covered slope.'},
#  {'idx': [2198, 3],
#   'image_id': 102903,
#   'id': 164203,
#   'caption': 'A person sitting on the ground with a snowboard on their feet'},
#  {'idx': [2198, 4],
#   'image_id': 102903,
#   'id': 171037,
#   'caption': 'A person sitting in the snow with a snowboard on.'},
#  {'idx': [2233, 1],
#   'image_id': 143440,
#   'id': 381491,
#   'caption': 'A person on a snowboard on a ramp.'},
#  {'idx': [2233, 4],
#   'image_id': 143440,
#   'id': 382649,
#   'caption': 'A man in blue shirt riding a snowboard next to people.'},
#  {'idx': [2298, 0],
#   'image_id': 351793,
#   'id': 732849,
#   'caption': 'A man riding a snowboard down a snow covered slope.'},
#  {'idx': [2298, 2],
#   'image_id': 351793,
#   'id': 742815,
#   'caption': 'A man wearing goggles and a red jacket rides a snowboard through water.'},
#  {'idx': [2467, 2],
#   'image_id': 89078,
#   'id': 768047,
#   'caption': 'A woman that is standing on a snowboard in the snow.'},
#  {'idx': [2494, 0],
#   'image_id': 83682,
#   'id': 791566,
#   'caption': 'a person riding a snowboard down a hill '},
#  {'idx': [2938, 0],
#   'image_id': 402118,
#   'id': 226754,
#   'caption': 'A person riding a snow board while flying through the air.'},
#  {'idx': [2967, 0],
#   'image_id': 456303,
#   'id': 451202,
#   'caption': 'A person on a snowboard who is performing a trick.'},
#  {'idx': [2967, 3],
#   'image_id': 456303,
#   'id': 454355,
#   'caption': 'a person jumping a snow board in the air'},
#  {'idx': [2967, 4],
#   'image_id': 456303,
#   'id': 825404,
#   'caption': 'This is a snowboard in the middle of a back flip.'},
#  {'idx': [3181, 0],
#   'image_id': 117508,
#   'id': 610982,
#   'caption': 'A person riding a snowboard down a snow covered slope.'},
#  {'idx': [3181, 2],
#   'image_id': 117508,
#   'id': 618407,
#   'caption': 'A young person riding a snowboard down a slope.'},
#  {'idx': [3497, 2],
#   'image_id': 421431,
#   'id': 336469,
#   'caption': 'A man in winter gear using a snowboard on a snowy slope.'},
#  {'idx': [3497, 3],
#   'image_id': 421431,
#   'id': 336646,
#   'caption': 'A person on a snowboard standing on top of a snowy hill.'},
#  {'idx': [3497, 4],
#   'image_id': 421431,
#   'id': 340219,
#   'caption': 'A man in black jacket on snowboard on top of hill next to trees.'},
#  {'idx': [3516, 0],
#   'image_id': 358296,
#   'id': 660249,
#   'caption': 'Snowboard rack at bottom of ski hill near building.'},
#  {'idx': [3516, 2],
#   'image_id': 358296,
#   'id': 670050,
#   'caption': 'A snow covered slope with a bunch of skis and snowboards on a rack.'},
#  {'idx': [3516, 4],
#   'image_id': 358296,
#   'id': 673029,
#   'caption': 'snow skis and snow boards in the holding rack'},
#  {'idx': [3562, 3],
#   'image_id': 52803,
#   'id': 728358,
#   'caption': 'a boy snow board at night by himself.'},
#  {'idx': [3562, 4],
#   'image_id': 52803,
#   'id': 729348,
#   'caption': 'A young person rides a snowboard at night.'},
#  {'idx': [3641, 1],
#   'image_id': 336602,
#   'id': 557405,
#   'caption': 'A man riding a snowboard down a snow covered slope.'},
#  {'idx': [3641, 2],
#   'image_id': 336602,
#   'id': 560759,
#   'caption': 'A person on a snowboard in the snow.'},
#  {'idx': [3641, 4],
#   'image_id': 336602,
#   'id': 570395,
#   'caption': 'a person riding a snow board on a snowy surface'},
#  {'idx': [3856, 2],
#   'image_id': 451532,
#   'id': 817221,
#   'caption': 'a group of people riding skis and snow boards '},
#  {'idx': [4308, 4],
#   'image_id': 74200,
#   'id': 391313,
#   'caption': 'Three snow boards behind trophies in a window.'},
#  {'idx': [4454, 2],
#   'image_id': 80273,
#   'id': 235754,
#   'caption': 'A man snowboards down a snowy hill. '},
#  {'idx': [4454, 4],
#   'image_id': 80273,
#   'id': 247151,
#   'caption': 'A person wearing a helmet and goggles riding a snowboard down the slopes.'},
#  {'idx': [4697, 0],
#   'image_id': 20334,
#   'id': 244308,
#   'caption': 'a person on a snow board laying on a snowy surface'},
#  {'idx': [4697, 1],
#   'image_id': 20334,
#   'id': 253230,
#   'caption': 'A person lying on the ground with a snowboard on his feet while other people ski by.'},
#  {'idx': [4697, 4],
#   'image_id': 20334,
#   'id': 260406,
#   'caption': 'Feet with a snowboard attached and people walking in the background.'},
#  {'idx': [4894, 1],
#   'image_id': 4375,
#   'id': 250440,
#   'caption': 'A photo of dozens of people on skis and snowboards and a mountain resort.'},
#  {'idx': [4897, 1],
#   'image_id': 276149,
#   'id': 151357,
#   'caption': 'many people and snowboards at the bottom of a snowy mountain'},
#  {'idx': [4897, 4],
#   'image_id': 276149,
#   'id': 160723,
#   'caption': 'snowboards and snowboarders standing at the bottom of a run.'},
#  {'idx': [4912, 1],
#   'image_id': 23359,
#   'id': 505853,
#   'caption': 'a man kind of high in the air while doing a snowboard trick '},
#  {'idx': [4984, 0],
#   'image_id': 88072,
#   'id': 169403,
#   'caption': 'A man on a snowboard at the bottom of the slope.'},
#  {'idx': [4984, 1],
#   'image_id': 88072,
#   'id': 169889,
#   'caption': 'A man riding a snowboard down a snow covered slope.'},
#  {'idx': [4984, 4],
#   'image_id': 88072,
#   'id': 175901,
#   'caption': 'A person standing on a snowboard in the snow at night.'},
#  {'idx': [5225, 0],
#   'image_id': 243968,
#   'id': 560014,
#   'caption': 'A man riding a snowboard is jumping over a hill.'},
#  {'idx': [5225, 1],
#   'image_id': 243968,
#   'id': 562807,
#   'caption': 'Man on snowboard jumping over snow capped hill.'},
#  {'idx': [5249, 1],
#   'image_id': 352361,
#   'id': 326189,
#   'caption': 'Man standing on large sized snow board sliding down mountain side.'},
#  {'idx': [5352, 3],
#   'image_id': 412621,
#   'id': 157160,
#   'caption': 'a snowboard preforming a crazy trick in town'},
#  {'idx': [5483, 0],
#   'image_id': 371241,
#   'id': 536248,
#   'caption': 'there are a few kids on snowboards on the snow'},
#  {'idx': [5483, 1],
#   'image_id': 371241,
#   'id': 537343,
#   'caption': 'A couple of kids on snowboards standing in the snow.'},
#  {'idx': [5483, 2],
#   'image_id': 371241,
#   'id': 538903,
#   'caption': 'Young children learning to snowboard together in the snow'},
#  {'idx': [5485, 4],
#   'image_id': 162902,
#   'id': 821767,
#   'caption': 'a group of people with snow board stand on the snow '},
#  {'idx': [5675, 0],
#   'image_id': 574178,
#   'id': 446159,
#   'caption': 'Two people carrying snowboards and walking through the snow.'},
#  {'idx': [5675, 1],
#   'image_id': 574178,
#   'id': 447908,
#   'caption': 'two people holding snow boards on a snowy surface'},
#  {'idx': [5675, 2],
#   'image_id': 574178,
#   'id': 448184,
#   'caption': 'two snow boarders carrying their snow boards across the snow'},
#  {'idx': [5675, 4],
#   'image_id': 574178,
#   'id': 453251,
#   'caption': 'Two friends walking through the snow carrying snowboards past a small cabin.'},
#  {'idx': [5699, 0],
#   'image_id': 174103,
#   'id': 377323,
#   'caption': 'A grouo of four snowboards out in front of a red colors building.'},
#  {'idx': [5699, 1],
#   'image_id': 174103,
#   'id': 377380,
#   'caption': 'Six snowboards are leaning against a red wall.'},
#  {'idx': [5699, 2],
#   'image_id': 174103,
#   'id': 378631,
#   'caption': 'A red building with snowboards leaning on it'},
#  {'idx': [5699, 3],
#   'image_id': 174103,
#   'id': 378934,
#   'caption': 'a number of snow boards leaning on a building'},
#  {'idx': [5699, 4],
#   'image_id': 174103,
#   'id': 381562,
#   'caption': 'A few snowboards are leaning against a building.'},
#  {'idx': [5917, 0],
#   'image_id': 212817,
#   'id': 394031,
#   'caption': 'A child on a snowboard going down a slope.'},
#  {'idx': [5917, 2],
#   'image_id': 212817,
#   'id': 395957,
#   'caption': 'The young child is posing for a picture before he snowboards down the hill. '},
#  {'idx': [5917, 3],
#   'image_id': 212817,
#   'id': 398033,
#   'caption': 'A boy is on a snowboard in shallow snow.'},
#  {'idx': [5921, 0],
#   'image_id': 164835,
#   'id': 512587,
#   'caption': 'A guy on a snow board in a snowy hill.'},
#  {'idx': [5921, 1],
#   'image_id': 164835,
#   'id': 577213,
#   'caption': 'A man leaning forward as the snowboard moves downhill.'},
#  {'idx': [5957, 0],
#   'image_id': 573968,
#   'id': 273001,
#   'caption': 'A person on a snowboard is standing on a rail.'},
#  {'idx': [5973, 1],
#   'image_id': 453792,
#   'id': 541907,
#   'caption': 'a female holding a bag and a snowboard in its cover'},
#  {'idx': [5973, 4],
#   'image_id': 453792,
#   'id': 551669,
#   'caption': 'A woman stands indoors next to a snowboard while holding a bag. '},
#  {'idx': [5996, 2],
#   'image_id': 579696,
#   'id': 272905,
#   'caption': 'Two people dressed in snow attire sitting against a brick wall with two snowboard leaning against it.'},
#  {'idx': [6040, 2],
#   'image_id': 573750,
#   'id': 440868,
#   'caption': 'A group of people with snowboards in the snow.'},
#  {'idx': [6169, 3],
#   'image_id': 470095,
#   'id': 48360,
#   'caption': 'A group of men riding snowboards down a snow covered slope.'},
#  {'idx': [6189, 3],
#   'image_id': 33104,
#   'id': 29775,
#   'caption': 'People with ski and snowboard equipment shaking hands.'},
#  {'idx': [6279, 0],
#   'image_id': 232625,
#   'id': 510560,
#   'caption': 'A guy on a snow board in the dark.'},
#  {'idx': [6279, 3],
#   'image_id': 232625,
#   'id': 552905,
#   'caption': 'A young man riding a snowboard on top of a rail.'},
#  {'idx': [6380, 0],
#   'image_id': 523955,
#   'id': 480533,
#   'caption': 'A man riding a snowboard down a snow covered slope.'},
#  {'idx': [6380, 2],
#   'image_id': 523955,
#   'id': 493643,
#   'caption': 'A person snowboards down a snowy hill. '},
#  {'idx': [6444, 1],
#   'image_id': 63563,
#   'id': 219298,
#   'caption': 'A person is riding high on a snowboard near a mountain.'},
#  {'idx': [6444, 2],
#   'image_id': 63563,
#   'id': 219454,
#   'caption': 'A woman in midair as she snowboards down a hill in the mountains.'},
#  {'idx': [6523, 4],
#   'image_id': 12413,
#   'id': 675013,
#   'caption': 'two people on snowboards are riding the ski lift'},
#  {'idx': [6538, 1],
#   'image_id': 257965,
#   'id': 547463,
#   'caption': 'A man riding a snowboard into the air.'},
#  {'idx': [6538, 3],
#   'image_id': 257965,
#   'id': 559628,
#   'caption': 'A person with a snowboard is jumping in the air.'},
#  {'idx': [6826, 2],
#   'image_id': 4554,
#   'id': 125973,
#   'caption': 'Six people standing on snowboards atop a snowy incline.'},
#  {'idx': [6949, 0],
#   'image_id': 549683,
#   'id': 516110,
#   'caption': 'A man trying to snowboard in the dark.'},
#  {'idx': [6950, 0],
#   'image_id': 100245,
#   'id': 223400,
#   'caption': 'A crowded ski slope filled with people riding snowboards and skis.'},
#  {'idx': [7029, 0],
#   'image_id': 288944,
#   'id': 47267,
#   'caption': 'A young boy kneeling down on a snowboard on a snow covered field.'},
#  {'idx': [7029, 2],
#   'image_id': 288944,
#   'id': 48149,
#   'caption': 'a small child riding a snow board on a snowy sloe'},
#  {'idx': [7029, 3],
#   'image_id': 288944,
#   'id': 53774,
#   'caption': 'A child wearing a snowboard on his knees in the snow.'},
#  {'idx': [7049, 0],
#   'image_id': 97679,
#   'id': 686964,
#   'caption': "A car with a snowboard on it's ski rack parked in a foggy parking lot next to two cars with empty ski racks. "},
#  {'idx': [7071, 3],
#   'image_id': 18728,
#   'id': 4419,
#   'caption': 'A gleeful boy with a snowboard plays in the snow.'},
#  {'idx': [7107, 0],
#   'image_id': 134098,
#   'id': 146364,
#   'caption': 'A person riding a snowboard down a snow covered slope.'},
#  {'idx': [7107, 1],
#   'image_id': 134098,
#   'id': 175737,
#   'caption': 'a person riding a snow board on a snowy surface'},
#  {'idx': [7121, 1],
#   'image_id': 74860,
#   'id': 810878,
#   'caption': 'A man sitting on the ground with a snowboard on his feet.'},
#  {'idx': [7121, 2],
#   'image_id': 74860,
#   'id': 813023,
#   'caption': 'A man sitting in the snow with his snowboard on. '},
#  {'idx': [7314, 1],
#   'image_id': 41077,
#   'id': 554298,
#   'caption': 'A man on a snowboard in the air above a pile of snow. '},
#  {'idx': [7663, 0],
#   'image_id': 44195,
#   'id': 656844,
#   'caption': 'A woman with a snowboard with a man standing next to her on a ski slope.'},
#  {'idx': [7663, 1],
#   'image_id': 44195,
#   'id': 657348,
#   'caption': 'Two people standing atop a snowy hill with snow boards in hand ready to head down the slope'},
#  {'idx': [7679, 4],
#   'image_id': 561512,
#   'id': 399213,
#   'caption': 'A man on a snowboard is soaring through the air. '},
#  {'idx': [7756, 0],
#   'image_id': 452687,
#   'id': 595254,
#   'caption': 'A picture of a snowboard covered in snow.'},
#  {'idx': [7756, 4],
#   'image_id': 452687,
#   'id': 747183,
#   'caption': 'A close up of a boot on a snow board in the snow'},
#  {'idx': [8274, 1],
#   'image_id': 184358,
#   'id': 247186,
#   'caption': 'A person getting on a snowboard while another person carries their snowboard up the slope.'},
#  {'idx': [8274, 3],
#   'image_id': 184358,
#   'id': 248998,
#   'caption': 'A man standing on top of a snowboard on a snow surface'},
#  {'idx': [8388, 0],
#   'image_id': 152211,
#   'id': 568457,
#   'caption': 'A person on a snow board high in the air.'},
#  {'idx': [8446, 4],
#   'image_id': 29138,
#   'id': 221303,
#   'caption': 'A group of people are standing on snowboards and skis.'},
#  {'idx': [8460, 1],
#   'image_id': 564636,
#   'id': 797685,
#   'caption': 'A man in red is jumping up with his snow board in the snow.'},
#  {'idx': [8559, 2],
#   'image_id': 187244,
#   'id': 303444,
#   'caption': 'A young man riding a snowboard down the side of a mountain.'},
#  {'idx': [8559, 3],
#   'image_id': 187244,
#   'id': 305994,
#   'caption': 'A man on a snowboard in the snow.'},
#  {'idx': [8559, 4],
#   'image_id': 187244,
#   'id': 312882,
#   'caption': 'A lone man in a red jacket stands on a green snowboard in the snow.'},
#  {'idx': [8753, 4],
#   'image_id': 267709,
#   'id': 529335,
#   'caption': 'A couple of people with snowboards in the snow.'},
#  {'idx': [8894, 0],
#   'image_id': 555456,
#   'id': 137520,
#   'caption': 'A person riding a snowboard on a snow covered slope.'},
#  {'idx': [8946, 0],
#   'image_id': 299254,
#   'id': 740592,
#   'caption': 'A man holding a snowboard on top of a snow covered hill.'},
#  {'idx': [8946, 1],
#   'image_id': 299254,
#   'id': 742704,
#   'caption': 'A man holds a snowboard against a snowy mountain background.'},
#  {'idx': [8946, 2],
#   'image_id': 299254,
#   'id': 742917,
#   'caption': 'A smiling man poses holding a snow board near some mountains.'},
#  {'idx': [8946, 3],
#   'image_id': 299254,
#   'id': 826328,
#   'caption': 'A man posing for a picture with a snowboard atop a snowy mountain.'},
#  {'idx': [9074, 1],
#   'image_id': 112949,
#   'id': 306143,
#   'caption': 'a man with a hat on a snow board on snow'},
#  {'idx': [9074, 2],
#   'image_id': 112949,
#   'id': 308288,
#   'caption': 'Black and white photograph of person on snowboard next to trees.'},
#  {'idx': [9109, 1],
#   'image_id': 440387,
#   'id': 195442,
#   'caption': 'Several people prepare to ski or snowboard on a snow slope.'},
#  {'idx': [9260, 1],
#   'image_id': 151965,
#   'id': 733360,
#   'caption': 'Two people holding snowboards are standing in the snow.'},
#  {'idx': [9260, 2],
#   'image_id': 151965,
#   'id': 735001,
#   'caption': 'People are carrying snowboards and walking in the snow.'},
#  {'idx': [9304, 3],
#   'image_id': 256743,
#   'id': 367366,
#   'caption': 'a young man holds a snow board '},
#  {'idx': [9304, 4],
#   'image_id': 256743,
#   'id': 368845,
#   'caption': 'A man holding a white snow board by some other kids'},
#  {'idx': [9327, 0],
#   'image_id': 387776,
#   'id': 349650,
#   'caption': 'A man jumping on snowboard with mountains and trees in background.'},
#  {'idx': [9327, 1],
#   'image_id': 387776,
#   'id': 349920,
#   'caption': 'A man on a snowboard performing jumps on a snowy hillside.'},
#  {'idx': [9327, 4],
#   'image_id': 387776,
#   'id': 357297,
#   'caption': 'A man on a snowboard does an air trick.'},
#  {'idx': [9347, 1],
#   'image_id': 213465,
#   'id': 322717,
#   'caption': 'A person on a snowboard stopped on a snowy hill.'},
#  {'idx': [9347, 4],
#   'image_id': 213465,
#   'id': 323653,
#   'caption': 'A person on a snowboard in the snow.'},
#  {'idx': [9376, 1],
#   'image_id': 417339,
#   'id': 713552,
#   'caption': 'a boy and a man standing together with some snowboards '},
#  {'idx': [9376, 3],
#   'image_id': 417339,
#   'id': 716474,
#   'caption': 'a man and a boy holding snowboards in the snow'},
#  {'idx': [9736, 0],
#   'image_id': 439658,
#   'id': 380822,
#   'caption': 'A man is holding a snowboard and standing next to a woman holding skis.'},
#  {'idx': [9736, 2],
#   'image_id': 439658,
#   'id': 385760,
#   'caption': 'A couple of people with a snowboard in the snow.'},
#  {'idx': [9853, 4],
#   'image_id': 154154,
#   'id': 230386,
#   'caption': 'A young man with a snowboard while a crowd looks on'},
#  {'idx': [9967, 4],
#   'image_id': 446473,
#   'id': 501488,
#   'caption': 'A person is jumping on a snowboard and is in the hair with his hands out and knees bent.'},
#  {'idx': [9969, 2],
#   'image_id': 185487,
#   'id': 798192,
#   'caption': 'a person riding a snow board in the air '},
#  {'idx': [9969, 4],
#   'image_id': 185487,
#   'id': 800076,
#   'caption': 'A snowboard with a kite for surfing in the air '},
#  {'idx': [10032, 0],
#   'image_id': 327255,
#   'id': 166290,
#   'caption': 'A man riding a snowboard across a snow covered slope.'},
#  {'idx': [10032, 3],
#   'image_id': 327255,
#   'id': 172914,
#   'caption': 'Skier on a snowboard at a ski resort.'},
#  {'idx': [10059, 0],
#   'image_id': 183843,
#   'id': 273308,
#   'caption': 'A man riding a snowboard across snow covered ground.'},
#  {'idx': [10059, 1],
#   'image_id': 183843,
#   'id': 274196,
#   'caption': 'A man riding a snowboard down a snow slope.'},
#  {'idx': [10059, 4],
#   'image_id': 183843,
#   'id': 282188,
#   'caption': 'A man standing on a snowboard on a small patch of snow at night.'},
#  {'idx': [10131, 1],
#   'image_id': 554347,
#   'id': 280615,
#   'caption': 'A boy on a snowboard looks down a hill.'},
#  {'idx': [10337, 0],
#   'image_id': 286036,
#   'id': 1823,
#   'caption': 'A group of people ski and snowboard together'},
#  {'idx': [10387, 0],
#   'image_id': 66412,
#   'id': 49928,
#   'caption': 'A young boy holding a snow board and a pair of shoes.'},
#  {'idx': [10424, 1],
#   'image_id': 483234,
#   'id': 774641,
#   'caption': 'Snowboards resting upon a tree, with man hiding inside it like fort'},
#  {'idx': [10424, 2],
#   'image_id': 483234,
#   'id': 775001,
#   'caption': 'A person holds a snowboard in front of a tree with snowboards leaning on it.'},
#  {'idx': [10424, 4],
#   'image_id': 483234,
#   'id': 776300,
#   'caption': 'a a couple of snowboards are up against a tree'},
#  {'idx': [10489, 2],
#   'image_id': 180983,
#   'id': 119349,
#   'caption': 'A young person stepping on a snowboard in preparation.'},
#  {'idx': [10489, 4],
#   'image_id': 180983,
#   'id': 125568,
#   'caption': 'A person stepping onto a snowboard in the snow'},
#  {'idx': [10579, 2],
#   'image_id': 493004,
#   'id': 442102,
#   'caption': 'A person on a snowboard rides on a hill.'},
#  {'idx': [10634, 0],
#   'image_id': 382801,
#   'id': 110255,
#   'caption': 'A man riding a snowboard down the side of a snow covered ski slope.'},
#  {'idx': [10639, 1],
#   'image_id': 480490,
#   'id': 224256,
#   'caption': 'a woman snowboarder holds her snowboard in the snow'},
#  {'idx': [10639, 2],
#   'image_id': 480490,
#   'id': 227430,
#   'caption': 'A person standing on a snowy mountain with a snowboard in hand.'},
#  {'idx': [10639, 3],
#   'image_id': 480490,
#   'id': 234369,
#   'caption': 'A person holding a snow board vertical in front of them a wooded snowy area.'},
#  {'idx': [10639, 4],
#   'image_id': 480490,
#   'id': 235731,
#   'caption': 'A young man is holding a snowboard in the snow.'},
#  {'idx': [10757, 1],
#   'image_id': 197847,
#   'id': 240815,
#   'caption': 'three people going down the hill on skiis and snowboards '},
#  {'idx': [11054, 1],
#   'image_id': 262873,
#   'id': 382528,
#   'caption': 'A man riding a snow board down a snow covered slope.'},
#  {'idx': [11200, 1],
#   'image_id': 492968,
#   'id': 216637,
#   'caption': 'A man riding a snowboard down a snow covered slope.'},
#  {'idx': [11200, 2],
#   'image_id': 492968,
#   'id': 218764,
#   'caption': 'A man on a snow board going down a snow covered hill.'},
#  {'idx': [11237, 0],
#   'image_id': 456199,
#   'id': 203076,
#   'caption': 'A young man riding a snowboard down a snow covered slope.'},
#  {'idx': [11309, 0],
#   'image_id': 237041,
#   'id': 259694,
#   'caption': 'A snowboard is left vacant in view of large snow capped mountains.'},
#  {'idx': [11309, 1],
#   'image_id': 237041,
#   'id': 260648,
#   'caption': 'A snowboard sticking out of the snow filled ground.'},
#  {'idx': [11309, 2],
#   'image_id': 237041,
#   'id': 261599,
#   'caption': 'A yellow and white snowboard is stuck into the snow on a ledge and a mountain range lays in the background.'},
#  {'idx': [11309, 3],
#   'image_id': 237041,
#   'id': 261767,
#   'caption': 'A snow board stuck in the snow in front of a large mountain.'},
#  {'idx': [11309, 4],
#   'image_id': 237041,
#   'id': 267692,
#   'caption': 'A snow board sitting upright with a view of a mountain.'},
#  {'idx': [11659, 2],
#   'image_id': 149014,
#   'id': 305598,
#   'caption': 'A person on a snowboard in the snow.'},
#  {'idx': [11659, 3],
#   'image_id': 149014,
#   'id': 313659,
#   'caption': 'A person on a blue snowboard going sledding between trees'},
#  {'idx': [11794, 1],
#   'image_id': 376246,
#   'id': 424624,
#   'caption': 'A person on a snowboard in the snow.'},
#  {'idx': [11794, 2],
#   'image_id': 376246,
#   'id': 427243,
#   'caption': 'A person riding a snowboard down a snow covered slope.'},
#  {'idx': [11876, 3],
#   'image_id': 345288,
#   'id': 231750,
#   'caption': 'a person jumping a snow board in the air'},
#  {'idx': [11929, 0],
#   'image_id': 485155,
#   'id': 609460,
#   'caption': 'A man is standing on a snowboard beside a bag of bottles.'},
#  {'idx': [11929, 2],
#   'image_id': 485155,
#   'id': 613318,
#   'caption': 'A man on his snow board at the ski slope'},
#  {'idx': [11953, 0],
#   'image_id': 549754,
#   'id': 179960,
#   'caption': 'Black and white action photograph of a snowboard competitor'},
#  {'idx': [12337, 0],
#   'image_id': 252383,
#   'id': 190594,
#   'caption': 'A group of three men riding snowboards on a snow covered slope.'},
#  {'idx': [12337, 1],
#   'image_id': 252383,
#   'id': 194200,
#   'caption': 'Three people sitting in the snow with snowboard on their feet.'},
#  {'idx': [12353, 4],
#   'image_id': 557829,
#   'id': 84599,
#   'caption': 'A woman riding a snowboard down the side of a ramp.'},
#  {'idx': [12372, 3],
#   'image_id': 446358,
#   'id': 401750,
#   'caption': 'A man on a snow board in front of trees'},
#  {'idx': [12396, 0],
#   'image_id': 381851,
#   'id': 230995,
#   'caption': 'many skis and snow boards on a snowy surface'},
#  {'idx': [12396, 1],
#   'image_id': 381851,
#   'id': 234532,
#   'caption': 'It is dusk, and the skiers have abandoned their skis and snow boards for social interaction.'},
#  {'idx': [12396, 2],
#   'image_id': 381851,
#   'id': 234865,
#   'caption': 'Several snow boards and skis waiting for skiers.'},
#  {'idx': [12396, 3],
#   'image_id': 381851,
#   'id': 237628,
#   'caption': 'Unused skis and snowboards are littered on the ground.'},
#  {'idx': [12459, 4],
#   'image_id': 486580,
#   'id': 707819,
#   'caption': 'a man on a snowboard is going down a hill'},
#  {'idx': [12484, 0],
#   'image_id': 248924,
#   'id': 111564,
#   'caption': 'A person on a snowboard is in the air preparing to land on a snowy slope.'},
#  {'idx': [12484, 3],
#   'image_id': 248924,
#   'id': 117726,
#   'caption': 'Photograph of man on snow board jumping through the air.'},
#  {'idx': [12484, 4],
#   'image_id': 248924,
#   'id': 126195,
#   'caption': 'A person jumping his or her snowboard in the air. '},
#  {'idx': [12534, 4],
#   'image_id': 262703,
#   'id': 107549,
#   'caption': 'a person riding a snow board falling onto their side '},
#  {'idx': [12598, 0],
#   'image_id': 517619,
#   'id': 222957,
#   'caption': 'A person snowboard on a  snow covered ground '},
#  {'idx': [12598, 3],
#   'image_id': 517619,
#   'id': 257700,
#   'caption': 'a couple of people on snowboards moving across a track'},
#  {'idx': [12634, 2],
#   'image_id': 74349,
#   'id': 679910,
#   'caption': 'A person on a snowboard jumping off a small hill. '},
#  {'idx': [12634, 3],
#   'image_id': 74349,
#   'id': 681809,
#   'caption': 'Someone doing a trick on their snow board at a ski slope'},
#  {'idx': [12707, 0],
#   'image_id': 276638,
#   'id': 62138,
#   'caption': 'People riding snowboards down a snow covered road.'},
#  {'idx': [12712, 1],
#   'image_id': 404464,
#   'id': 356931,
#   'caption': 'A snowboard sliding very gently across the snow in an enclosure.'},
#  {'idx': [12712, 2],
#   'image_id': 404464,
#   'id': 357279,
#   'caption': 'A person on a snowboard getting ready for competition.'},
#  {'idx': [12712, 3],
#   'image_id': 404464,
#   'id': 358707,
#   'caption': 'Man on snowboard riding under metal roofed enclosed area.'},
#  {'idx': [12722, 0],
#   'image_id': 355513,
#   'id': 32158,
#   'caption': 'A man standing on his snowboard  by the woods,'},
#  {'idx': [12722, 2],
#   'image_id': 355513,
#   'id': 39769,
#   'caption': 'A young man standing on top of a snow board in the snow.'},
#  {'idx': [12722, 4],
#   'image_id': 355513,
#   'id': 49171,
#   'caption': 'A man on a snowboard posing for a picture. '},
#  {'idx': [12846, 0],
#   'image_id': 165029,
#   'id': 265581,
#   'caption': 'A man with a snowboard next to a man with a mask.'},
#  {'idx': [12846, 1],
#   'image_id': 165029,
#   'id': 268566,
#   'caption': 'Man with snowboard standing next to another wearing a mask and crazy hands.'},
#  {'idx': [12846, 2],
#   'image_id': 165029,
#   'id': 268716,
#   'caption': 'A man holding a snowboard next to a man in scary costume.'},
#  {'idx': [13201, 0],
#   'image_id': 422017,
#   'id': 259993,
#   'caption': 'A man holding a snowboard stands on a hill in the snow while a mountain range is in the distance.'},
#  {'idx': [13201, 1],
#   'image_id': 422017,
#   'id': 260134,
#   'caption': 'A man holding a snowboard looking down a mountain.'},
#  {'idx': [13201, 2],
#   'image_id': 422017,
#   'id': 261958,
#   'caption': 'A man standing next to a snowboard on a ski slope.'},
#  {'idx': [13201, 4],
#   'image_id': 422017,
#   'id': 269890,
#   'caption': 'A man holding a snow board looking at a snowy ski slope.'},
#  {'idx': [13224, 3],
#   'image_id': 383046,
#   'id': 311936,
#   'caption': 'A man on a snow board on a big snowy hill.'},
#  {'idx': [13238, 0],
#   'image_id': 151589,
#   'id': 548173,
#   'caption': 'A blue snowboard sitting on top of a snow covered slope.'},
#  {'idx': [13238, 2],
#   'image_id': 151589,
#   'id': 555556,
#   'caption': "The snowboard is laid on it's edge in the snow."},
#  {'idx': [13238, 4],
#   'image_id': 151589,
#   'id': 559144,
#   'caption': 'A blue snowboard laying on the side of a mountain.'},
#  {'idx': [13252, 0],
#   'image_id': 526040,
#   'id': 743037,
#   'caption': 'A person on a snowboard has fallen in the snow.'},
#  {'idx': [13252, 2],
#   'image_id': 526040,
#   'id': 826817,
#   'caption': 'A man riding a snowboard on a snow filled slope.'},
#  {'idx': [13419, 4],
#   'image_id': 31482,
#   'id': 608436,
#   'caption': 'a child riding a snow board on a snowy surface'},
#  {'idx': [13427, 1],
#   'image_id': 94944,
#   'id': 375860,
#   'caption': 'A group of people on slope with snowboards and skis.'},
#  {'idx': [13427, 2],
#   'image_id': 94944,
#   'id': 377696,
#   'caption': 'man on his knees with his snow board still attached, hands on hips'},
#  {'idx': [13427, 3],
#   'image_id': 94944,
#   'id': 379718,
#   'caption': 'A skier on skies and a snowboarder carrying a snowboard on a mountain slope.'},
#  {'idx': [13435, 0],
#   'image_id': 34508,
#   'id': 133725,
#   'caption': 'A person on a snowboard on a mountain slope.'},
#  {'idx': [13435, 2],
#   'image_id': 34508,
#   'id': 136980,
#   'caption': 'A person jumping a snowboard on a snowy hilllside'},
#  {'idx': [13501, 0],
#   'image_id': 479149,
#   'id': 99255,
#   'caption': 'A skier on a snow board taking a leap above a snow covered mountain.'},
#  {'idx': [13501, 1],
#   'image_id': 479149,
#   'id': 100206,
#   'caption': 'Man doing snowboard trick in air on snow.'},
#  {'idx': [13859, 0],
#   'image_id': 365099,
#   'id': 273651,
#   'caption': 'A man riding a snowboard down a snow covered slope.'},
#  {'idx': [13945, 0],
#   'image_id': 118564,
#   'id': 300788,
#   'caption': 'a person jumping a snow board in the air'},
#  {'idx': [14044, 0],
#   'image_id': 117645,
#   'id': 349967,
#   'caption': 'A man riding a snowboard down a snow covered slope.'},
#  {'idx': [14044, 1],
#   'image_id': 117645,
#   'id': 354899,
#   'caption': 'A person riding a snowboard down a snowy slope.'},
#  {'idx': [14047, 2],
#   'image_id': 263647,
#   'id': 756451,
#   'caption': 'a person on a snow board laying in some snow '},
#  {'idx': [14047, 4],
#   'image_id': 263647,
#   'id': 761114,
#   'caption': 'a person riding a snow board on the ground '},
#  {'idx': [14367, 4],
#   'image_id': 431272,
#   'id': 178373,
#   'caption': 'A person standing on a snowboard in the snow. '},
#  {'idx': [14615, 2],
#   'image_id': 201498,
#   'id': 479805,
#   'caption': 'Someone is one the ground with snowboard on their feet.'},
#  {'idx': [14615, 3],
#   'image_id': 201498,
#   'id': 483021,
#   'caption': 'A person with a snow board laying in the snow.'},
#  {'idx': [14855, 0],
#   'image_id': 316007,
#   'id': 597472,
#   'caption': 'Two guys on the ski slope while one holds his snow board behind his back. '},
#  {'idx': [14855, 1],
#   'image_id': 316007,
#   'id': 599398,
#   'caption': 'A young man holding a snowboard behind his back.'},
#  {'idx': [14855, 2],
#   'image_id': 316007,
#   'id': 601480,
#   'caption': 'two guys one is carrying his snow board on his back'},
#  {'idx': [14855, 3],
#   'image_id': 316007,
#   'id': 604528,
#   'caption': 'A man holding a snowboard and a man behind him waving. '},
#  {'idx': [14855, 4],
#   'image_id': 316007,
#   'id': 607702,
#   'caption': 'The man in blue is holding a snowboard while the man behind waves. '},
#  {'idx': [14918, 0],
#   'image_id': 290948,
#   'id': 79794,
#   'caption': 'Two people on a ski slope with snow boards on their feet.'},
#  {'idx': [14918, 1],
#   'image_id': 290948,
#   'id': 83892,
#   'caption': 'Two people sit in the snow with snowboards on.'},
#  {'idx': [14918, 2],
#   'image_id': 290948,
#   'id': 87117,
#   'caption': 'Two kids on snowboards on a snowy hill.'},
#  {'idx': [14918, 3],
#   'image_id': 290948,
#   'id': 93690,
#   'caption': 'Two people sitting in the snow with snowboards on their feet.'},
#  {'idx': [15045, 0],
#   'image_id': 350668,
#   'id': 413820,
#   'caption': 'A man riding a snowboard down a snow covered slope.'},
#  {'idx': [15080, 0],
#   'image_id': 493279,
#   'id': 52742,
#   'caption': 'A woman walking next to a snowboard on a ski covered slope.'},
#  {'idx': [15364, 2],
#   'image_id': 332582,
#   'id': 765548,
#   'caption': 'The snowboarder riding a snowboard on a slope.'},
#  {'idx': [15364, 4],
#   'image_id': 332582,
#   'id': 766901,
#   'caption': 'A person on a snowboard riding in the snow.'},
#  {'idx': [15399, 0],
#   'image_id': 174332,
#   'id': 204553,
#   'caption': 'A man holding a snowboard standing at the bottom of steps.'},
#  {'idx': [15399, 1],
#   'image_id': 174332,
#   'id': 219643,
#   'caption': 'A man holding a snowboard and standing at the bottom of a staircase.'},
#  {'idx': [15399, 3],
#   'image_id': 174332,
#   'id': 229009,
#   'caption': 'A young man is holding his snowboard at the bottom of stairs.'},
#  {'idx': [15479, 0],
#   'image_id': 150212,
#   'id': 169339,
#   'caption': 'A snowboard sitting on a snow covered slope.'},
#  {'idx': [15479, 1],
#   'image_id': 150212,
#   'id': 174628,
#   'caption': "The snow board is propped up on it's end."},
#  {'idx': [15479, 2],
#   'image_id': 150212,
#   'id': 175669,
#   'caption': 'A snowboard is vertical in the white snow.'},
#  {'idx': [15479, 3],
#   'image_id': 150212,
#   'id': 177304,
#   'caption': 'A snowboard stuck in the snow standing upright.'},
#  {'idx': [15479, 4],
#   'image_id': 150212,
#   'id': 179350,
#   'caption': 'Looking past a snowboard in the snow to a city beyond'},
#  {'idx': [15601, 4],
#   'image_id': 424196,
#   'id': 261475,
#   'caption': 'A man attaching himself to a snow board on top of snow.'},
#  {'idx': [15724, 0],
#   'image_id': 67218,
#   'id': 207604,
#   'caption': 'A group of people riding snow boards on top of a slope.'},
#  {'idx': [15724, 3],
#   'image_id': 67218,
#   'id': 222493,
#   'caption': 'A group of kids are playing on snowboards outside '},
#  {'idx': [15748, 2],
#   'image_id': 151299,
#   'id': 216864,
#   'caption': 'A man is jumping a snowboard off of a ramp.'},
#  {'idx': [15758, 1],
#   'image_id': 425906,
#   'id': 603924,
#   'caption': 'a person jumping a snow board in the air '},
#  {'idx': [15959, 2],
#   'image_id': 512455,
#   'id': 716467,
#   'caption': 'A person performs a jump on a snowboard on a snowy hill.'},
#  {'idx': [16060, 0],
#   'image_id': 361171,
#   'id': 780770,
#   'caption': 'a person riding a snow board in the air '},
#  {'idx': [16060, 2],
#   'image_id': 361171,
#   'id': 787763,
#   'caption': 'a man that is jumping a snowboard through the air'},
#  {'idx': [16060, 3],
#   'image_id': 361171,
#   'id': 787838,
#   'caption': 'An athlete with a snow board is performing on a city street.'},
#  {'idx': [16060, 4],
#   'image_id': 361171,
#   'id': 787934,
#   'caption': 'A man on a snow board making a jump'},
#  {'idx': [16143, 1],
#   'image_id': 495131,
#   'id': 781970,
#   'caption': 'A man who is jumping up on a snowboard but not on the snow.'},
#  {'idx': [16143, 3],
#   'image_id': 495131,
#   'id': 785807,
#   'caption': 'A man that is on a snowboard on a box.'},
#  {'idx': [16143, 4],
#   'image_id': 495131,
#   'id': 786611,
#   'caption': 'A man with a snow board is performing on a obstacle.'},
#  {'idx': [16379, 2],
#   'image_id': 393469,
#   'id': 23979,
#   'caption': 'A man standing next to a snowboard in the snow.'},
#  {'idx': [16766, 2],
#   'image_id': 489850,
#   'id': 141538,
#   'caption': 'Three snowboarders in snow gear and with snowboards standing next to a sing written in Japanese.'},
#  {'idx': [16766, 3],
#   'image_id': 489850,
#   'id': 141670,
#   'caption': 'Three women are posing with snowboard in the snow. '},
#  {'idx': [16766, 4],
#   'image_id': 489850,
#   'id': 142432,
#   'caption': 'Three ladies with snow board standing under a sign on a slope.'},
#  {'idx': [17071, 2],
#   'image_id': 326128,
#   'id': 790567,
#   'caption': 'A man that is standing with a snowboard in the snow.'},
#  {'idx': [17071, 3],
#   'image_id': 326128,
#   'id': 790966,
#   'caption': 'A man standing on a snowboard on a mountain peak.'},
#  {'idx': [17226, 1],
#   'image_id': 89047,
#   'id': 356725,
#   'caption': 'A snow board rider taking a jump in the air.'},
#  {'idx': [17284, 0],
#   'image_id': 228166,
#   'id': 104663,
#   'caption': 'A man riding a snowboard down a snow covered slope.'},
#  {'idx': [17332, 3],
#   'image_id': 330205,
#   'id': 21693,
#   'caption': 'A person on a snowboard does an air trick.'},
#  {'idx': [17352, 0],
#   'image_id': 440840,
#   'id': 148479,
#   'caption': 'A man riding a snowboard down a snow covered slope.'},
#  {'idx': [17352, 3],
#   'image_id': 440840,
#   'id': 176043,
#   'caption': 'a person riding a snow board on a snowy surface'},
#  {'idx': [17449, 0],
#   'image_id': 62858,
#   'id': 205584,
#   'caption': 'A man holding a red snowboard while standing in snow.'},
#  {'idx': [17449, 2],
#   'image_id': 62858,
#   'id': 211584,
#   'caption': 'A man stands with his snowboard on a snowy hill.'},
#  {'idx': [17449, 3],
#   'image_id': 62858,
#   'id': 212469,
#   'caption': 'A young man is holding his snowboard in the snow.'},
#  {'idx': [17485, 3],
#   'image_id': 184978,
#   'id': 468350,
#   'caption': 'a person riding a snow board on a snowy surface'},
#  {'idx': [17629, 2],
#   'image_id': 238074,
#   'id': 730819,
#   'caption': 'A man is standing on a snowboard in the snow.'},
#  {'idx': [17641, 0],
#   'image_id': 497719,
#   'id': 353325,
#   'caption': 'A man riding a snowboard down a slope with many hills.'},
#  {'idx': [17641, 2],
#   'image_id': 497719,
#   'id': 356274,
#   'caption': 'A person in a cap rides a snowboard down a snowy hill.'},
#  {'idx': [17641, 4],
#   'image_id': 497719,
#   'id': 359016,
#   'caption': 'A man is leaning down on his snowboard to get down a hill.'},
#  {'idx': [17750, 2],
#   'image_id': 50482,
#   'id': 517793,
#   'caption': 'a bunch of snow board and skis sit next to each other on some snow'},
#  {'idx': [17826, 3],
#   'image_id': 111910,
#   'id': 411691,
#   'caption': 'A person on a snowboard sitting in the snow in the middle of a trail.'},
#  {'idx': [17951, 2],
#   'image_id': 473075,
#   'id': 417908,
#   'caption': 'A man competing in a snow board competition in front of a crowd of spectators.'},
#  {'idx': [17951, 3],
#   'image_id': 473075,
#   'id': 418793,
#   'caption': 'a person jumping a snow board in the air'},
#  {'idx': [18032, 0],
#   'image_id': 486803,
#   'id': 536346,
#   'caption': 'a person that is on a snowboard in the air'},
#  {'idx': [18032, 4],
#   'image_id': 486803,
#   'id': 548262,
#   'caption': 'A person jumping midair on a snowboard while a person photographs.'},
#  {'idx': [18252, 0],
#   'image_id': 122281,
#   'id': 487947,
#   'caption': 'Three men holding snowboards on top of a mountain'},
#  {'idx': [18270, 2],
#   'image_id': 259056,
#   'id': 230975,
#   'caption': 'A man in black holds up a camera as a man on top of a gray snowboard hovers in the air.'},
#  {'idx': [18270, 4],
#   'image_id': 259056,
#   'id': 239582,
#   'caption': 'A man performing in a snow board and another trying to capture the moment with a camera.'},
#  {'idx': [18340, 0],
#   'image_id': 574507,
#   'id': 115750,
#   'caption': 'A man riding a snowboard through the air above a snow covered field.'},
#  {'idx': [18340, 2],
#   'image_id': 574507,
#   'id': 167038,
#   'caption': 'A person on a snowboard in the air near a group of people.'},
#  {'idx': [18340, 3],
#   'image_id': 574507,
#   'id': 181342,
#   'caption': 'a person jumping a snow board in the air'},
#  {'idx': [18392, 0],
#   'image_id': 21905,
#   'id': 418897,
#   'caption': 'A man on a snowboard flying through the air'},
#  {'idx': [18437, 0],
#   'image_id': 546658,
#   'id': 403142,
#   'caption': 'A man in camouflage snow suit next to snowboard on ice.'},
#  {'idx': [18437, 4],
#   'image_id': 546658,
#   'id': 412586,
#   'caption': 'A person standing with a snow board in the right hand.'},
#  {'idx': [18524, 4],
#   'image_id': 423619,
#   'id': 71674,
#   'caption': 'a man attemping a snowboard trick down a pipe'},
#  {'idx': [18535, 0],
#   'image_id': 195697,
#   'id': 286288,
#   'caption': 'A person riding a snowboard down a hill.'},
#  {'idx': [18535, 1],
#   'image_id': 195697,
#   'id': 403342,
#   'caption': 'A man riding a snowboard down the side of a snow covered slope.'},
#  {'idx': [18535, 2],
#   'image_id': 195697,
#   'id': 403351,
#   'caption': 'A person in grey and tan jacket riding a snowboard on slope.'},
#  {'idx': [18539, 0],
#   'image_id': 323067,
#   'id': 207953,
#   'caption': 'a man laying on a pile of snow next to a snowboard inside of a building.'},
#  {'idx': [18547, 2],
#   'image_id': 36032,
#   'id': 790804,
#   'caption': 'Person on a snowboard in mid air next to snowy mountain.'},
#  {'idx': [18563, 0],
#   'image_id': 171622,
#   'id': 517491,
#   'caption': 'The person is riding their snowboard down the hill.'},
#  {'idx': [18566, 3],
#   'image_id': 529838,
#   'id': 122280,
#   'caption': 'a snowboard high up in the air while doing a trick'},
#  {'idx': [18756, 4],
#   'image_id': 209357,
#   'id': 823751,
#   'caption': 'Three men posing for a picture with a snow board in one of the mans hands '},
#  {'idx': [18806, 1],
#   'image_id': 152946,
#   'id': 608991,
#   'caption': 'Two snowboarders with their snowboards standing in the snow.'},
#  {'idx': [18909, 1],
#   'image_id': 291251,
#   'id': 201839,
#   'caption': 'a person jumping a snow board in the air'},
#  {'idx': [18909, 2],
#   'image_id': 291251,
#   'id': 204710,
#   'caption': 'a person  wearing a snowboard jumping above the snow '},
#  {'idx': [18909, 4],
#   'image_id': 291251,
#   'id': 223388,
#   'caption': 'A person riding on a snowboard doing a round on the snow.'},
#  {'idx': [19315, 0],
#   'image_id': 338291,
#   'id': 589583,
#   'caption': 'A young person holding a snowboard while wearing a helmet.'},
#  {'idx': [19315, 1],
#   'image_id': 338291,
#   'id': 743984,
#   'caption': 'There is a man holding a snowboard in his arm.'},
#  {'idx': [19315, 2],
#   'image_id': 338291,
#   'id': 744821,
#   'caption': 'A person carrying a snow board with it his left hand.'},
#  {'idx': [19536, 0],
#   'image_id': 390704,
#   'id': 660202,
#   'caption': 'a person riding a snow board on a snowy surface '},
#  {'idx': [19536, 3],
#   'image_id': 390704,
#   'id': 665860,
#   'caption': 'A man riding a snowboard on top of  snow covered ground.'},
#  {'idx': [19536, 4],
#   'image_id': 390704,
#   'id': 667546,
#   'caption': 'A person performs snowboard tricks while a crowd looks on.'},
#  {'idx': [19600, 3],
#   'image_id': 387916,
#   'id': 59652,
#   'caption': 'Multiple skiers and snow boards on a mountain.'},
#  {'idx': [19691, 1],
#   'image_id': 505242,
#   'id': 43313,
#   'caption': 'A man standing on a snow board in the snow.'},
#  {'idx': [19691, 4],
#   'image_id': 505242,
#   'id': 44816,
#   'caption': 'A man stands on a snowboard on a snowy cliff in front of rocks.'},
#  {'idx': [19792, 2],
#   'image_id': 574804,
#   'id': 812102,
# ...
#  {'idx': [33627, 1],
#   'image_id': 534903,
#   'id': 206091,
#   'caption': 'A man riding a snowboard down a snow covered slope.'},
#  {'idx': [33680, 0],
#   'image_id': 231795,
#   'id': 422166,
#   'caption': 'A kid standing there looking at his snowboard on the snow covered walkway. '},
#  {'idx': [33680, 3],
#   'image_id': 231795,
#   'id': 431433,
#   'caption': 'A person standing over a snowboard in the snow.'},
#  {'idx': [33829, 0],
#   'image_id': 90306,
#   'id': 527145,
#   'caption': 'A man in the air on a snowboard above a blue bed. '},
#  {'idx': [33829, 1],
#   'image_id': 90306,
#   'id': 527601,
#   'caption': 'A man is on a snowboard in the air'},
#  {'idx': [33829, 4],
#   'image_id': 90306,
#   'id': 530946,
#   'caption': 'a man is on a snowboard above his bed '},
#  {'idx': [33858, 0],
#   'image_id': 127451,
#   'id': 24478,
#   'caption': 'Two men riding snowboards in a snow storm down a slope.'},
#  {'idx': [33858, 2],
#   'image_id': 127451,
#   'id': 29182,
#   'caption': 'Two men use their snowboards to go down a snowy incline.'},
#  {'idx': [34002, 0],
#   'image_id': 549462,
#   'id': 489666,
#   'caption': 'Someone jumping in the air on their snowboard at the ski slope. '},
#  {'idx': [34002, 1],
#   'image_id': 549462,
#   'id': 490020,
#   'caption': 'A  person on a snowboard doing tricks down a snowy slope.'},
#  {'idx': [34002, 3],
#   'image_id': 549462,
#   'id': 491658,
#   'caption': 'a man jumping down part of a hill with a snowboard '},
#  {'idx': [34002, 4],
#   'image_id': 549462,
#   'id': 491661,
#   'caption': 'A person on a snowboard is performing a trick.'},
#  {'idx': [34230, 0],
#   'image_id': 77754,
#   'id': 694384,
#   'caption': 'A man riding a snowboard on top of  snow covered ground.'},
#  {'idx': [34230, 1],
#   'image_id': 77754,
#   'id': 696883,
#   'caption': 'A man sitting on a snowboard on a snowy slope.'},
#  {'idx': [34230, 2],
#   'image_id': 77754,
#   'id': 697792,
#   'caption': 'A man with a snowboard on his feet sits alone in the snow.'},
#  {'idx': [34606, 0],
#   'image_id': 66243,
#   'id': 621635,
#   'caption': 'a man holding a blue snow board in his hand on the snowy mountain '},
#  {'idx': [34606, 1],
#   'image_id': 66243,
#   'id': 622040,
#   'caption': 'A person holding a snow board in the mountains.'},
#  {'idx': [34682, 0],
#   'image_id': 455279,
#   'id': 785720,
#   'caption': 'a person with a snow board kneeling in the snow'},
#  {'idx': [34682, 3],
#   'image_id': 455279,
#   'id': 794582,
#   'caption': 'The woman smiles while posing in the snow with her snowboard on. '},
#  {'idx': [34738, 4],
#   'image_id': 310196,
#   'id': 729548,
#   'caption': 'a person on a snowboard weaves down a mountain slope.'},
#  {'idx': [34776, 0],
#   'image_id': 193429,
#   'id': 742330,
#   'caption': 'Man sitting in snow with snowboard attached to shoes. '},
#  {'idx': [34776, 1],
#   'image_id': 193429,
#   'id': 826168,
#   'caption': 'A man sitting down with a snowboard strapped on'},
#  {'idx': [34776, 4],
#   'image_id': 193429,
#   'id': 828486,
#   'caption': 'A man sits in the snow with a snowboard still on his feet.'},
#  {'idx': [34797, 2],
#   'image_id': 522639,
#   'id': 468162,
#   'caption': 'a number of people with snow boards on a snowy surface'},
#  {'idx': [34890, 2],
#   'image_id': 125257,
#   'id': 140941,
#   'caption': 'a person riding a snow board on a snowy slope'},
#  {'idx': [34890, 3],
#   'image_id': 125257,
#   'id': 142036,
#   'caption': 'A man on a snowboard on a groomed slope.'},
#  {'idx': [34995, 0],
#   'image_id': 541917,
#   'id': 657841,
#   'caption': 'Shoes, a chair, and snowboard sit on a porch'},
#  {'idx': [34995, 1],
#   'image_id': 541917,
#   'id': 660214,
#   'caption': 'A snowboard and boots are sitting outside a door.\n\n\n\n'},
#  {'idx': [34995, 2],
#   'image_id': 541917,
#   'id': 660508,
#   'caption': 'a snow board leaning against a wall near a chair '},
#  {'idx': [34995, 3],
#   'image_id': 541917,
#   'id': 661807,
#   'caption': 'Small enclosed porch with snowboard and shoes next to chair.'},
#  {'idx': [34995, 4],
#   'image_id': 541917,
#   'id': 662923,
#   'caption': 'An enclosed patio area with a snowboard and snowboarding boots.'},
#  {'idx': [35043, 0],
#   'image_id': 97278,
#   'id': 428541,
#   'caption': 'Young man on top of a snowboard wearing maroon jacket. '},
#  {'idx': [35043, 1],
#   'image_id': 97278,
#   'id': 431874,
#   'caption': 'a young boy is standing on a snowboard '},
#  {'idx': [35043, 2],
#   'image_id': 97278,
#   'id': 436710,
#   'caption': 'A man riding a snowboard on top of snow covered ground.'},
#  {'idx': [35090, 2],
#   'image_id': 504559,
#   'id': 236155,
#   'caption': 'two young men hold snowboards on a platform'},
#  {'idx': [35090, 4],
#   'image_id': 504559,
#   'id': 245329,
#   'caption': 'Two men holding snowboards while smiling in front of a backdrop.'},
#  {'idx': [35106, 4],
#   'image_id': 214127,
#   'id': 447962,
#   'caption': 'A person with a snow board high in the air.'},
#  {'idx': [35259, 2],
#   'image_id': 414522,
#   'id': 460884,
#   'caption': 'A man riding a snowboard on top of a snow covered slope.'},
#  {'idx': [35386, 0],
#   'image_id': 139294,
#   'id': 149055,
#   'caption': 'A figurine of a little boy riding a snow board in yellow pants.'},
#  {'idx': [35386, 3],
#   'image_id': 139294,
#   'id': 196236,
#   'caption': 'A clay figure is on a snowboard on the snow.'},
#  {'idx': [35386, 4],
#   'image_id': 139294,
#   'id': 196485,
#   'caption': 'Two young people on snow boards under the caption Docku.'},
#  {'idx': [35419, 3],
#   'image_id': 298586,
#   'id': 804725,
#   'caption': 'Black and white photograph of person on snowboard in street.'},
#  {'idx': [35483, 0],
#   'image_id': 200058,
#   'id': 563993,
#   'caption': 'A person on a snowboard in the snow.'},
#  {'idx': [35483, 2],
#   'image_id': 200058,
#   'id': 567992,
#   'caption': 'A woman standing next to a snow board on a snow covered slope.'},
#  {'idx': [35483, 4],
#   'image_id': 200058,
#   'id': 570986,
#   'caption': 'A person standing on the snowboard on top of the snow. '},
#  {'idx': [35487, 0],
#   'image_id': 281725,
#   'id': 150766,
#   'caption': 'A man riding a snowboard over a snow covered slope.'},
#  {'idx': [35487, 3],
#   'image_id': 281725,
#   'id': 179986,
#   'caption': 'a person riding a snow board on a snowy slope'},
#  {'idx': [35707, 0],
#   'image_id': 42661,
#   'id': 490476,
#   'caption': 'A man riding a snowboard down a snow covered slope.'},
#  {'idx': [35707, 1],
#   'image_id': 42661,
#   'id': 493008,
#   'caption': 'A person standing on a snowboard with knees bent and arms out on the snow with trees and snowy hills behind.'},
#  {'idx': [35707, 4],
#   'image_id': 42661,
#   'id': 498471,
#   'caption': 'A person on a snowboard going down a run.'},
#  {'idx': [35725, 2],
#   'image_id': 240655,
#   'id': 257338,
#   'caption': 'a guy on a snowboard going accros a bench'},
#  {'idx': [35951, 2],
#   'image_id': 36539,
#   'id': 280897,
#   'caption': 'A man on snowboard standing by a mountain.'},
#  {'idx': [35958, 3],
#   'image_id': 375521,
#   'id': 300002,
#   'caption': 'Two people in ski gear looking at a snow board at night'},
#  {'idx': [36019, 0],
#   'image_id': 224368,
#   'id': 527464,
#   'caption': 'A man on a snowboard grinding a rail. '},
#  {'idx': [36098, 2],
#   'image_id': 573770,
#   'id': 517743,
#   'caption': 'a couple of people on snow boards make their way through the snow'},
#  {'idx': [36255, 1],
#   'image_id': 220382,
#   'id': 750685,
#   'caption': 'A boy snowboards down a snowy hill on a snowy day.'},
#  {'idx': [36255, 3],
#   'image_id': 220382,
#   'id': 755723,
#   'caption': 'A young boy snowboards down a hill in winter.'},
#  {'idx': [36255, 4],
#   'image_id': 220382,
#   'id': 757235,
#   'caption': 'a guy riding a snow board down a slight hill'},
#  {'idx': [36448, 1],
#   'image_id': 42953,
#   'id': 358585,
#   'caption': 'Several people with skis and snowboards boarding a helicopter.'},
#  {'idx': [36543, 0],
#   'image_id': 259099,
#   'id': 479280,
#   'caption': 'A person riding a snowboard across a snow covered slope.'},
#  {'idx': [36543, 1],
#   'image_id': 259099,
#   'id': 479799,
#   'caption': 'A person on a snow board on a snowy hill.'},
#  {'idx': [36543, 3],
#   'image_id': 259099,
#   'id': 482916,
#   'caption': 'A person is riding a snowboard through the snow.'},
#  {'idx': [36603, 0],
#   'image_id': 561958,
#   'id': 128752,
#   'caption': 'many people holding skis and snow boards on a snowy surface'},
#  {'idx': [36654, 4],
#   'image_id': 330911,
#   'id': 829032,
#   'caption': 'It looked like the man was riding his snow board on a city bridge.'},
#  {'idx': [36807, 1],
#   'image_id': 407650,
#   'id': 729044,
#   'caption': 'A young person jumping their snow board in the air as they ski down a mountain.'},
#  {'idx': [36807, 2],
#   'image_id': 407650,
#   'id': 730760,
#   'caption': 'a person jumping a snow board in the air '},
#  {'idx': [36836, 2],
#   'image_id': 188958,
#   'id': 117594,
#   'caption': 'A group of people with snowboards outside of a lodge.'},
#  {'idx': [36900, 0],
#   'image_id': 206560,
#   'id': 126838,
#   'caption': 'a person jumping a snow board in the air'},
#  {'idx': [36900, 1],
#   'image_id': 206560,
#   'id': 127159,
#   'caption': 'A person riding a colorful snowboard in mid-air'},
#  {'idx': [36945, 1],
#   'image_id': 302405,
#   'id': 329770,
#   'caption': 'A couple of people on snowboards in the snow.'},
#  {'idx': [36972, 4],
#   'image_id': 96625,
#   'id': 825304,
#   'caption': 'A person doing a trick on a snowboard off a hill.'},
#  {'idx': [37101, 0],
#   'image_id': 484485,
#   'id': 603907,
#   'caption': 'A snowboarder holding a snowboard standing under a sign.'},
#  {'idx': [37101, 1],
#   'image_id': 484485,
#   'id': 605923,
#   'caption': 'The snowboard is almost as big as the snowboarder.'},
#  {'idx': [37136, 0],
#   'image_id': 190689,
#   'id': 387508,
#   'caption': 'A person doing a trick on a snowboard off of a hill.'},
#  {'idx': [37136, 2],
#   'image_id': 190689,
#   'id': 388699,
#   'caption': 'A person in the air on a snowboard doing a jumping trick and clouds covering the sun in the sky.'},
#  {'idx': [37396, 4],
#   'image_id': 246532,
#   'id': 39310,
#   'caption': 'a person riding a snow board on a snowy slope'},
#  {'idx': [37397, 0],
#   'image_id': 303342,
#   'id': 446630,
#   'caption': 'A man riding a snowboard on top of a snow covered slope.'},
#  {'idx': [37656, 0],
#   'image_id': 319908,
#   'id': 2414,
#   'caption': 'A man holds a snowboard inside a building with snow while people hang out in the background.'},
#  {'idx': [37656, 4],
#   'image_id': 319908,
#   'id': 8153,
#   'caption': 'Young man posing with his snow board inside a building.'},
#  {'idx': [37923, 2],
#   'image_id': 279203,
#   'id': 84798,
#   'caption': 'Two people prepare their snowboards for the hills.'},
#  {'idx': [37923, 4],
#   'image_id': 279203,
#   'id': 102909,
#   'caption': 'People standing on the snow with snowboards and skis'},
#  {'idx': [38044, 2],
#   'image_id': 35411,
#   'id': 76744,
#   'caption': "A snow covered mountain with a person riding a snowboard down it's slope."},
#  {'idx': [38195, 1],
#   'image_id': 227855,
#   'id': 63471,
#   'caption': 'A man riding a snowboard through the air.'},
#  {'idx': [38197, 1],
#   'image_id': 248953,
#   'id': 757553,
#   'caption': 'A man performs a trick on a snowboard on a snowy day.'},
#  {'idx': [38197, 3],
#   'image_id': 248953,
#   'id': 759090,
#   'caption': 'A person on a snowboard on a metal railing.'},
#  {'idx': [38393, 0],
#   'image_id': 288408,
#   'id': 211298,
#   'caption': 'A woman is standing on a snowboard indoors.'},
#  {'idx': [38393, 1],
#   'image_id': 288408,
#   'id': 214223,
#   'caption': 'A woman in blue jeans stands on a snowboard on a floor.'},
#  {'idx': [38393, 2],
#   'image_id': 288408,
#   'id': 215552,
#   'caption': 'a woman wearing a red shirt is standing on a snowboard thats on a carpet'},
#  {'idx': [38393, 3],
#   'image_id': 288408,
#   'id': 215732,
#   'caption': 'A woman stands on her snowboard inside a house.'},
#  {'idx': [38393, 4],
#   'image_id': 288408,
#   'id': 221429,
#   'caption': 'A woman riding a snowboard on top of tile.'},
#  {'idx': [38647, 1],
#   'image_id': 435894,
#   'id': 649820,
#   'caption': 'A snowboard is seen laying on another piece of equipment.'},
#  {'idx': [38647, 2],
#   'image_id': 435894,
#   'id': 652469,
#   'caption': 'A snowboard holds down fabric fastened to a structure.'},
#  {'idx': [38647, 3],
#   'image_id': 435894,
#   'id': 654926,
#   'caption': 'the snowboard is holding down the edge of the tent '},
#  {'idx': [38647, 4],
#   'image_id': 435894,
#   'id': 657446,
#   'caption': 'A snowboard sitting on top of a tent.'},
#  {'idx': [39191, 0],
#   'image_id': 190014,
#   'id': 733449,
#   'caption': 'the young man is set to snowboard at this skiing location. '},
#  {'idx': [39191, 2],
#   'image_id': 190014,
#   'id': 737586,
#   'caption': 'A person is holding a snowboard on a pile of snow.'},
#  {'idx': [39191, 3],
#   'image_id': 190014,
#   'id': 738270,
#   'caption': 'a man holding a snow board standing on a snowy hill'},
#  {'idx': [39191, 4],
#   'image_id': 190014,
#   'id': 742749,
#   'caption': 'A man wearing a helmet holds a snowboard in the snow.'},
#  {'idx': [39252, 1],
#   'image_id': 497514,
#   'id': 74492,
#   'caption': 'A man riding a snowboard on a snow covered ski slope.'},
#  {'idx': [39252, 2],
#   'image_id': 497514,
#   'id': 80507,
#   'caption': 'A man is performing a snowboard jump and appears that he is hooked to the lift.'},
#  {'idx': [39252, 4],
#   'image_id': 497514,
#   'id': 83954,
#   'caption': 'A man jumping on a snow board in the snow '},
#  {'idx': [39278, 3],
#   'image_id': 431058,
#   'id': 698741,
#   'caption': 'a panorama photo of a man doing a trick in the air on his snow board '},
#  {'idx': [39394, 0],
#   'image_id': 380330,
#   'id': 490709,
#   'caption': 'A man on a snowboard standing on a rail.'},
#  {'idx': [39505, 0],
#   'image_id': 465323,
#   'id': 304066,
#   'caption': 'a person with a snow board sit on some snow '},
#  {'idx': [39505, 2],
#   'image_id': 465323,
#   'id': 305770,
#   'caption': 'A person sitting in the snow with a snowboard on their feet near some trees.'},
#  {'idx': [39836, 0],
#   'image_id': 403792,
#   'id': 11092,
#   'caption': 'Two snowboards attached to feet above snow and trees.'},
#  {'idx': [39836, 3],
#   'image_id': 403792,
#   'id': 14545,
#   'caption': 'snowboarders with two different snowboards on a slope.'},
#  {'idx': [39836, 4],
#   'image_id': 403792,
#   'id': 821690,
#   'caption': 'Two snowboarders with red and green snowboards sit on a chairlift above a ski area.'},
#  {'idx': [39841, 0],
#   'image_id': 24106,
#   'id': 532483,
#   'caption': 'A man riding a snowboard off the side of a ramp.'},
#  {'idx': [39866, 0],
#   'image_id': 15797,
#   'id': 541185,
#   'caption': 'A man riding a snowboard down the side of a snow covered slope.'},
#  {'idx': [39866, 2],
#   'image_id': 15797,
#   'id': 549144,
#   'caption': 'A person on a snowboard sitting on the top of a mountain.'},
#  {'idx': [39866, 3],
#   'image_id': 15797,
#   'id': 558954,
#   'caption': 'A person on a snowboard in the snow.'},
#  {'idx': [39866, 4],
#   'image_id': 15797,
#   'id': 559779,
#   'caption': 'A person sitting in the snow with a snowboard attached to their feet and snow covered areas around them.'},
#  {'idx': [39951, 3],
#   'image_id': 450709,
#   'id': 154346,
#   'caption': 'A woman riding a snowboard down a snow covered slope.'},
#  {'idx': [39951, 4],
#   'image_id': 450709,
#   'id': 161264,
#   'caption': 'A person on a snowboard riding on a slope.'},
#  {'idx': [40042, 2],
#   'image_id': 232241,
#   'id': 291222,
#   'caption': 'Two people with snowboards on their feet on their knees in the snow.'},
#  {'idx': [40042, 3],
#   'image_id': 232241,
#   'id': 292110,
#   'caption': 'A man in a white jacket and a man in a red jacket kneeling with snowboards on their feet. '},
#  {'idx': [40042, 4],
#   'image_id': 232241,
#   'id': 296640,
#   'caption': 'two men kneeling with snowboards in the mountains.'},
#  {'idx': [40121, 2],
#   'image_id': 579294,
#   'id': 617712,
#   'caption': 'A person on a snowboard on a short ski slope ramp in front of a building.'},
#  {'idx': [40208, 1],
#   'image_id': 503808,
#   'id': 782025,
#   'caption': 'A guy on a snowboard going down a mountain.'},
#  {'idx': [40208, 3],
#   'image_id': 503808,
#   'id': 783456,
#   'caption': 'A man riding a snowboard down the side of a snow covered slope.'},
#  {'idx': [40259, 3],
#   'image_id': 442040,
#   'id': 196626,
#   'caption': 'Many people ski and snowboard down ski slopes.'}]

# %% [markdown]
# idxはAttnGANのindexに対応しているらしい。
# んー、正直使えなさそうなデータなのでスキップ
